# %% [markdown]
# # Modeling Antibiotic Responce Through Datamining in the MIMICIII Dataset
# ### Group 2: Garrett Eickelberg, Kishore Anekalla, Yikuan Li

# %%
#libraries
import numpy as np
from numpy import nan
import pandas as pd
import matplotlib.pyplot as plt
import psycopg2
import collections
import asyncio
import getpass
import re
from datetime import datetime as dt
import os,sys,re
import urllib3
import prettytable
from collections import Counter
import seaborn as sns
import random


from sklearn.externals.joblib import Memory
memory = Memory(cachedir='/tmp', verbose=0)
#@memory.cache above any def fxn.

# %matplotlib inline
plt.style.use('ggplot')

from notebook.services.config import ConfigManager
cm = ConfigManager()
cm.update('livereveal', {
        'width': 1024,
        'height': 768,
        'scroll': True,
})

# %load_ext autotime

# %% [markdown]
# #reserach question:
# -Can we predict the 5/7 day ab course by 48 hours after culture/ab start for icu patients?
#
# #cohort criteria:
# - YES- only adult patients (over 18 yo)  (~n= 38,000 age >18)
# - with sterile culture
# - and ab start within the same 24 hours time window (bulk will be in first 24 hours but possibly not).
#
#
# Three subsets:
# – Started on antibiotics, after 48hrs, negculture, discontinue	: neg/stop
# - 48hrs, negculture, but continue full course 7, 10, or 14 days: neg/continue
# – Positive culture, continue full course.Predict whether kept on antibiotics:
#
#     pos/continue
#
# 	Infected with positive culture
#
# 	Infected with negative culture (ie a false positive)
#
#
# #components: data cleaning, model building

# %%
#code used to ping the postgres mimic server. 

conn = psycopg2.connect(dbname="mimic", user="student", host="luolabwkstn01.fsm.northwestern.edu", port="5432",
                        password=getpass.getpass(prompt='Password:'.format()))
cur=conn.cursor()

query_schema = 'SET search_path to ' + "mimiciii" + ';'
# Out:
# Password:········
# time: 5.81 s

# %%
#initializing the dataframes. 
final_events_df = pd.read_csv('/Users/geickelb1/Desktop/PhD_Misc/HSIP_442_Yuan_Lao/final_events_df_04-16-18.csv', index_col=0)
ABrx_16sterile_ntnul = pd.read_csv('/Users/geickelb1/Desktop/PhD_Misc/HSIP_442_Yuan_Lao/ABrx_16sterile_ntnul_04-16-18.csv', index_col=0)
ptinfo_ICUsterile_16 = pd.read_csv('/Users/geickelb1/Desktop/PhD_Misc/HSIP_442_Yuan_Lao/ptinfo_ICUsterile_16_04-16-18.csv', index_col=0)
ptinfo_ICUsterile_16_pt = pd.read_csv('/Users/geickelb1/Desktop/PhD_Misc/HSIP_442_Yuan_Lao/ptinfo_ICUsterile_pt_16_04-16-18.csv', index_col=0)
ABrx_16sterile_ntnul_pts = pd.read_csv('/Users/geickelb1/Desktop/PhD_Misc/HSIP_442_Yuan_Lao/ABrx_16sterile_ntnul_pts_04-16-18.csv', index_col=0)

ABrx_16sterile_ntnul_pts = pd.read_csv('/Users/geickelb1/Desktop/PhD_Misc/HSIP_442_Yuan_Lao/sterile_pt_df3_4-16-18.csv', index_col=0)

ABrx_merged_16sterile_ntnul=ABrx_16sterile_ntnul

#dictionary
#final_events_df: result of merger between event rows of INPUTEVENTS/CHARTEVENTS_MV for patients who are 16yo+. 
#ABrx_merged_16sterile_ntnul: result of merger between event rows of Rx after curating for AB for patients who are 16yo+. 
#all rows are an hadm_id associated with a sterile culture that is associated with an antiboitic and is during the patient's icu stay window
 

#ptinfo_ICUsterile_16: this is all the hospital and icu admission and patient data for patients >=16yo, 
#with a sterile culture associated with hadm_id that occured during icu timewindow
#ABrx_16sterile_ntnul_pts= patients list in ABrx_16sterile_ntnul
# Out:
# /Users/geickelb1/anaconda/envs/rpy-env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# time: 3.52 s

# %%
# Out:
# time: 7.4 ms

# %%
ABrx_16sterile_ntnul.head()
# Out:
#     row_id  subject_id  hadm_id  icustay_id   startdate     enddate drug_type  \
# 0  2366833       24915   194424    267059.0  2182-12-10  2182-12-10      MAIN
# 1  2366088       24915   194424    267059.0  2182-11-29  2182-12-24      MAIN
# 2  2366064       24915   194424    267059.0  2182-11-17  2182-11-20      MAIN
# 3  2366065       24915   194424    267059.0  2182-11-17  2182-11-29      MAIN
# 4  2367574       24915   194424    267059.0  2183-01-12  2183-01-15      MAIN
#
#                   drug drug_name_poe drug_name_generic    ...    last_wardid  \
# 0           Daptomycin           NaN               NaN    ...             52
# 1  Imipenem-Cilastatin           NaN               NaN    ...             52
# 2       Vancomycin HCl           NaN               NaN    ...             52
# 3  Imipenem-Cilastatin           NaN               NaN    ...             52
# 4         Levofloxacin           NaN               NaN    ...             52
#
#              chartdate            charttime spec_itemid spec_type_desc  \
# 0  2182-11-29 00:00:00  2182-11-29 12:19:00       70012  BLOOD CULTURE
# 1  2182-11-29 00:00:00  2182-11-29 12:19:00       70012  BLOOD CULTURE
# 2  2182-11-29 00:00:00  2182-11-29 12:19:00       70012  BLOOD CULTURE
# 3  2182-11-29 00:00:00  2182-11-29 12:19:00       70012  BLOOD CULTURE
# 4  2182-11-29 00:00:00  2182-11-29 12:19:00       70012  BLOOD CULTURE
#
#   sterile_dur_icu       culture_hadm_date_rng   first_sterile_date  \
# 0            True  63 days 07:46:00.000000000  2182-11-12 01:50:00
# 1            True  63 days 07:46:00.000000000  2182-11-12 01:50:00
# 2            True  63 days 07:46:00.000000000  2182-11-12 01:50:00
# 3            True  63 days 07:46:00.000000000  2182-11-12 01:50:00
# 4            True  63 days 07:46:00.000000000  2182-11-12 01:50:00
#
#   culture_count  pt_ab_db
# 0            85     cv_ab
# 1            85     cv_ab
# 2            85     cv_ab
# 3            85     cv_ab
# 4            85     cv_ab
#
# [5 rows x 43 columns]
# time: 89.8 ms

# %% [markdown]
# # next steps:
#
# data cleaning/cohort selection:
#
#     1)filter cohort to only patients who have sterile culture, antibiotic administration within 24 hours and ICU stay >1 day.
#     2)add # of consecutive days of antibiotic dose for each patient
#
# model selection:
#
#     1)import clinical data and build simple logit model
#     2)use more sophisticated data mining to improve AUC

# %%
#age of pt in Rx
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 6)
ABrx_16sterile_ntnul_pts['first_admit_age'].sort_values(ascending=True).plot.hist(100)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/geickelb1/anaconda/envs/rpy-env/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['dtype']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# # ROTATION PROJECT
# so it looks like th

# %% [markdown]
# 4-6-18:
# from mimiciii team: “Because the table actually contains each instance of the prescribed antibiotics for all the patients - not just the names of the antibiotics. So after you have all the drugs in PRESCRIPTIONS which are antibiotics, you can query for them to get all prescribed antibiotics for a patient.”
#
#
# this means we can potentially just use the prescriptions table for cohort selection? Makes me wonder why we didn't use this initially? did we think this wasn't comprehensive?

# %% [markdown]
# #todo 4/9/18
#
#
#
# mv       9730
# cv       8229
# cv&mv    1415
# both       62
# total:   19436 : have sterile culture, >16yo, been rx an AB.
#
# vs our combined cv/mv: 13713
# print(t1),print(t2),print(t3),print(t4)
#
#
# look at the 5000 pts we didn't capture, and look at which ab they are prescribed.
# need to check: are these antibacterials?
#
#
#
# look at our previous final event list, how do we define when AB usage stopped? relook at notes.
# xxx- we were going to use consecutive events to define timeframe.
#
#
# randomly select ~20 pts, and compare timeings between prescription table and events table.
# this is inleu of boxplot.
#
#
# for cohort
#
# redo the cv/mv coding but on prescription ab table so its only patients who have antibiotics in one, other, or both.
#
# as long as our pt selection is close to RX table.
#
#
# ##4/11/18
#
# found that the ABrx table has some prescriptions for people that don't have an icu stay. these need to get filtered out. numbers need to get regenerated

# %% [markdown]
# #todo after genetics class 4/11:
# #3) investigate 20 random false pos/neg patients

# %%
#task1
#look at the x pts we not captured in either/both rx and event, and look at which ab they are prescribed.
#need to check: are these antibacterials?


def rx_event_random_sample_fxn(event,rx):
    event_pt_list= list(event['subject_id'].unique())
    rx_pt_list = list(rx['subject_id'].unique())
    pt_not_captured_in_event = list(set(rx_pt_list)-set(event_pt_list))
    pt_not_captured_in_rx = list(set(event_pt_list)-set(rx_pt_list))

    #defining patients not captured in events and rx (false positives and false negs)
    print(len(pt_not_captured_in_event),  'pt in rx not in events')
    print(len(pt_not_captured_in_rx), 'pt in events not in rx' )

    print(len(rx_pt_list), "pt in rx")
    print(len(event_pt_list), 'pt in event')
    print(len(rx_pt_list)-len(event_pt_list), '# of patient difference between event and rx. this is difference in first 2' )

    random.seed(a=4112018)
    rnd_pt_not_captured_in_event = list(random.sample(pt_not_captured_in_event, 20))
    rnd_pt_not_captured_in_rx = list(random.sample(pt_not_captured_in_rx, 20))
    return(rnd_pt_not_captured_in_event, rnd_pt_not_captured_in_rx)

rx_event_random_sample_fxn(final_events_df, ABrx_merged_16sterile_ntnul)
#rnd_pt_not_captured_in_event output
#rnd_pt_not_captured_in_rx output
# Out:
# 4919 pt in rx not in events
# 769 pt in events not in rx
# 14903 pt in rx
# 10753 pt in event
# 4150 # of patient difference between event and rx. this is difference in first 2
# ([26984,
#   10032,
#   17773,
#   5740,
#   23840,
#   27810,
#   26560,
#   3924,
#   4576,
#   79038,
#   3253,
#   71808,
#   11993,
#   16756,
#   5578,
#   24571,
#   89906,
#   19297,
#   2850,
#   15759],
#  [4754,
#   91079,
#   75576,
#   15048,
#   497,
#   4602,
#   20804,
#   6042,
#   65412,
#   85195,
#   17485,
#   9664,
#   19016,
#   28365,
#   7605,
#   24807,
#   26043,
#   77053,
#   15055,
#   71821])
# time: 35.4 ms

# %%
length_of_stay.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input
# 193889  2181-06-03 00:27:00   FinishedRunning           0.0
# 201901  2156-12-23 20:01:00   FinishedRunning           0.0
# 201902  2156-12-24 20:01:00   FinishedRunning           0.0
# 201903  2156-12-25 20:27:00   FinishedRunning           0.0
#
#        ordercategorydescription  linkorderid                          label
# 1753                        NaN          NaN              Vancomycin/Random
# 8359                        NaN          NaN              Vancomycin/Trough
# 8360                        NaN          NaN                Vancomycin/Peak
# 8361                        NaN          NaN              Vancomycin/Random
# 8579                        NaN          NaN              Vancomycin/Random
# 8580                        NaN          NaN              Vancomycin/Trough
# 8581                        NaN          NaN              Vancomycin/Random
# 8582                        NaN          NaN              Vancomycin/Random
# 8583                        NaN          NaN              Vancomycin/Random
# 8584                        NaN          NaN              Vancomycin/Random
# 10525                       NaN          NaN              Vancomycin/Trough
# 10526                       NaN          NaN              Vancomycin/Random
# 11865                       NaN          NaN              Vancomycin/Trough
# 11866                       NaN          NaN              Vancomycin/Trough
# 11867                       NaN          NaN                Vancomycin/Peak
# 11868                       NaN          NaN              Vancomycin/Trough
# 11869                       NaN          NaN                Vancomycin/Peak
# 11870                       NaN          NaN              Vancomycin/Trough
# 11871                       NaN          NaN                Vancomycin/Peak
# 28827                       NaN          NaN              Vancomycin/Random
# 28828                       NaN          NaN                Vancomycin/Peak
# 28829                       NaN          NaN                Vancomycin/Peak
# 28830                       NaN          NaN              Vancomycin/Trough
# 28831                       NaN          NaN              Vancomycin/Random
# 29774                       NaN          NaN                Vancomycin/Peak
# 29775                       NaN          NaN              Vancomycin/Trough
# 29776                       NaN          NaN              Vancomycin/Trough
# 29777                       NaN          NaN                Vancomycin/Peak
# 29778                       NaN          NaN              Vancomycin/Trough
# 32273                       NaN          NaN              Vancomycin/Trough
# 32274                       NaN          NaN                Vancomycin/Peak
# 94865                 Drug Push    1267821.0                   Levofloxacin
# 94866                 Drug Push    4001434.0                  Ciprofloxacin
# 120599                Drug Push    4768558.0                      Cefazolin
# 120600                Drug Push    4651990.0                      Cefazolin
# 120601                Drug Push    9363653.0                      Cefazolin
# 175290                Drug Push    8752742.0                      Cefazolin
# 175291                Drug Push    8479404.0                      Cefazolin
# 175292                Drug Push    9356865.0                      Cefazolin
# 175293                Drug Push    2530914.0                      Cefazolin
# 175294                Drug Push    9682858.0                      Cefazolin
# 175295                Drug Push    9057962.0                      Cefazolin
# 175296                Drug Push    3949155.0                      Cefazolin
# 175297                Drug Push    8408906.0                      Cefazolin
# 193888                Drug Push     474291.0  Ampicillin/Sulbactam (Unasyn)
# 193889                Drug Push    5487534.0                     Vancomycin
# 201901                Drug Push    3985757.0                    Ceftriaxone
# 201902                Drug Push    2877548.0                    Ceftriaxone
# 201903                Drug Push    3797881.0                    Ceftriaxone
# time: 46.1 ms

# %% [markdown]
# writeup pt not in prescriptions:
#
# subject id: 1869
# hadm_id: 186017
# row_id: 44004540
# itemid: 855
# label: Vancomycin/Random
# start time: 2125-10-12 12:00:00
# Patient is not in prescription list. reading his chart note, it sounds like he is on a respirator in bed care, and has bed sores which were treated with antibiotics. not sure why this wouldn't be recorded in RX table, but this patient was already in ICU before rx antibiotics, so this pt isn't compatable with our study anyway.
#
# #1
# subject id: 3
# hadm_id: 118936
# row_id: 34307312
# itemid: 855
#
# this patient has been given vancomysin, and yet is not in PRESCRIPTIONS table, but is in the icu database. this patient is from CV. IDK what to make of this.
#  1.  Vancomycin 1 g intravenously q.24h. for a level of less
# than 15 (started on [**2101-10-4**]).
#
# The patient was started on
# gentamicin and piperacillin/tazobactam in addition to the
# levofloxacin, metronidazole, and vancomycin he was already
# taking for right lower extremity cellulitis prior to
# admission for empiric coverage of a presumed gram-negative
# urosepsis, and he was aggressively hydrated with intravenous
# fluids.
#
# On [**2101-10-21**], his levofloxacin and metronidazole was
# discontinued, and he was started on fluconazole given the
# growth of yeast on urine culture.  He was taken off of
# gentamicin on hospital day three, and his fluconazole was
# discontinued on hospital day five (as per the Infectious
# Disease Service).  He was taken off of vancomycin on
# [**2101-10-28**], and his piperacillin/tazobactam was
# discontinued on [**2101-10-29**].
#
# ...he was already on ab. what to do about this?
#
#
# #2
# subject_id = 195
# hadm_id = 118936
#
# this patient is in both chartevents and inputevents_mv. in chartevents they have an itemid=855, which is vancomysin.
# it was given over 3.5 days, 12/12, 12/13, 12/14, 12/14.
# charttime= 2167-12-12.  can't figure out why she's not in prescriptions.

# %%
#looking in prescriptions for patients not selected that were selected in events
pt_not_captured_in_event_df = ABrx__16sterile_ntnul.loc[ABrx_merged_16sterile_ntnul.loc[:,'subject_id'].isin(pt_not_captured_in_event),:]
pt_not_captured_in_event_df.loc[pt_not_captured_in_event_df.loc[:,'pt_ab_db']=='mv_ab',:]
# Out:
#         row_id  subject_id  hadm_id icustay_id   startdate     enddate  \
# 1493   1474783       24656   157923     235199  2167-12-19  2167-12-19
# 1494   1474785       24656   157923     235199  2167-12-19  2167-12-22
# 1721   1394191       26027   159497     204624  2206-02-07  2206-02-10
# 2019     62916       26220   196422     277119  2150-04-12  2150-04-16
# 2601   1396915       26932   106260     257552  2184-09-27  2184-09-27
# 2602   1396916       26932   106260     257552  2184-09-27  2184-09-27
# 2603   1396918       26932   106260     257552  2184-09-27  2184-09-28
# 2604   1396921       26932   106260     257552  2184-09-28  2184-09-29
# 2605   1396925       26932   106260     257552  2184-09-30  2184-10-01
# 2606   1396926       26932   106260     257552  2184-09-30  2184-10-03
# 2607   1396929       26932   106260     257552  2184-10-01  2184-10-02
# 2896   1135377       26431   137423     280957  2170-03-14  2170-03-14
# 2897   1135378       26431   137423     280957  2170-03-14  2170-03-14
# 2929    233917       26406   128270     230878  2119-02-09  2119-02-10
# 3016    817096       26288   198365     281487  2146-08-20  2146-08-24
# 3183    111441       25905   143877     260776  2188-02-19  2188-02-20
# 4657   2671220       27809   170734     224527  2161-09-05  2161-09-09
# 4658   2671934       27809   170734     224527  2161-09-05  2161-09-09
# 5073    614406       27476   134491     201091  2148-11-27  2148-11-28
# 5268    997907       27615   151228     238320  2151-09-25  2151-09-25
# 6254   1206381       27953   104446     252418  2143-12-28  2143-12-30
# 2896       MAIN               Ciprofloxacin IV                            NaN
# 2897       MAIN                     Vancomycin                            NaN
# 2929       MAIN                    CeftriaXONE                            NaN
# 3016       MAIN      Sulfameth/Trimethoprim DS      Sulfameth/Trimethoprim DS
# 3183       MAIN      Sulfameth/Trimethoprim DS      Sulfameth/Trimethoprim DS
# 4657       MAIN                   Azithromycin                   Azithromycin
# 4658       MAIN                    CeftriaXONE                            NaN
# 5073       MAIN                   Levofloxacin                   Levofloxacin
# 5268       MAIN                    Clindamycin                    Clindamycin
# 6254       MAIN                     Vancomycin                            NaN
# 8074       MAIN              Ciprofloxacin HCl              Ciprofloxacin HCl
# 8479       MAIN                   Azithromycin                   Azithromycin
# 8480       MAIN                    CeftriaXONE                            NaN
# 9065       MAIN     Piperacillin-Tazobactam Na                            NaN
# 9066       MAIN     Piperacillin-Tazobactam Na                            NaN
# 9067       MAIN                     Vancomycin                            NaN
# 9122       MAIN                     Vancomycin                            NaN
# 9123       MAIN                     Vancomycin                            NaN
# 9124       MAIN                      CefazoLIN                            NaN
# ...         ...                            ...                            ...
# 86834      MAIN                     Cephalexin                     Cephalexin
# 86835      MAIN      Sulfameth/Trimethoprim DS      Sulfameth/Trimethoprim DS
# 87294      MAIN   Erythromycin 0.5% Ophth Oint   Erythromycin 0.5% Ophth Oint
# 88591      MAIN                    CeftriaXONE                            NaN
# 88592      MAIN                   Levofloxacin                   Levofloxacin
# 89402      MAIN                     Cephalexin                     Cephalexin
# 89404      MAIN               Ciprofloxacin IV                            NaN
# 89405      MAIN                     Vancomycin                            NaN
# 89479      MAIN                       CefePIME                            NaN
# 89480      MAIN                    CeftriaXONE                            NaN
# 89879      MAIN  Neomycin-Polymyxin-Bacitracin  Neomycin-Polymyxin-Bacitracin
# 89880      MAIN  Neomycin-Polymyxin-Bacitracin  Neomycin-Polymyxin-Bacitracin
# 90385      MAIN                     Vancomycin                            NaN
# 91482      MAIN                       CefePIME                            NaN
# 91483      MAIN         MetRONIDAZOLE (FLagyl)                            NaN
# 91484      MAIN                     Vancomycin                            NaN
# 91485      MAIN        Piperacillin-Tazobactam                            NaN
# 91756      MAIN      Sulfameth/Trimethoprim DS      Sulfameth/Trimethoprim DS
# 91757      MAIN     Piperacillin-Tazobactam Na                            NaN
# 91758      MAIN                     Vancomycin                            NaN
# 92193      MAIN                     Vancomycin                            NaN
# 92194      MAIN                     Vancomycin                            NaN
# 92195      MAIN                     Vancomycin                            NaN
# 92196      MAIN                     Vancomycin                            NaN
# 92197      MAIN                     Vancomycin                            NaN
# 92198      MAIN                     Vancomycin                            NaN
# 93674      MAIN        Sulfameth/Trimethoprim         Sulfameth/Trimethoprim
# 93867      MAIN      Sulfameth/Trimethoprim SS      Sulfameth/Trimethoprim SS
# 94379      MAIN                     Vancomycin                            NaN
# 94380      MAIN                    Clindamycin                    Clindamycin
#
#                    drug_name_generic   ...    form_unit_disp     route  \
# 1493                             NaN   ...               BAG        IV
# 1494                             NaN   ...              VIAL        IV
# 1721             Bacitracin Ointment   ...              TUBE        TP
# 2019                    Azithromycin   ...               TAB        PO
# 2601                             NaN   ...               BAG        IV
# 2602                             NaN   ...               BAG        IV
# 2603                             NaN   ...                mg        IV
# 2604                             NaN   ...               BAG        IV
# 2605                             NaN   ...               BAG        IV
# 2606                             NaN   ...               BAG        IV
# 2607                             NaN   ...              VIAL        IV
# 2896                             NaN   ...               BAG        IV
# 2897                             NaN   ...               BAG        IV
# 2929                             NaN   ...               BAG        IV
# 3016       Sulfameth/Trimethoprim DS   ...               TAB     PO/NG
# 3183       Sulfameth/Trimethoprim DS   ...               TAB     PO/NG
# 4657                    Azithromycin   ...               TAB        PO
# 4658                             NaN   ...               BAG        IV
# 5073                    Levofloxacin   ...               TAB     PO/NG
# 5268                     Clindamycin   ...               CAP        PO
# 6254                             NaN   ...               BAG        IV
# 8074               Ciprofloxacin HCl   ...               TAB     PO/NG
# 8479                    Azithromycin   ...               TAB        PO
# 8480                             NaN   ...               BAG        IV
# 9065                             NaN   ...               BAG        IV
# 9066                             NaN   ...               BAG        IV
# 9067                             NaN   ...               BAG        IV
# 9122                             NaN   ...               BAG        IV
# 9123                             NaN   ...               BAG        IV
# 9124                             NaN   ...               BAG        IV
# ...                              ...   ...               ...       ...
# 86834                     Cephalexin   ...               CAP     PO/NG
# 86835      Sulfameth/Trimethoprim DS   ...               TAB     PO/NG
# 87294   Erythromycin 0.5% Ophth Oint   ...              TUBE  LEFT EYE
# 88591                            NaN   ...               BAG        IV
# 88592                   Levofloxacin   ...               TAB     PO/NG
# 89402                     Cephalexin   ...               CAP     PO/NG
# 89404                            NaN   ...               BAG        IV
# 89405                            NaN   ...               BAG        IV
# 89479                            NaN   ...                mL        IV
# 89480                            NaN   ...               BAG        IV
# 89879  Neomycin-Polymyxin-Bacitracin   ...              TUBE        TP
# 89880  Neomycin-Polymyxin-Bacitracin   ...              TUBE        TP
# 90385                            NaN   ...               BAG        IV
# 91482                            NaN   ...                mL        IV
# 91483                            NaN   ...               BAG        IV
# 91484                            NaN   ...               BAG        IV
# 91485                            NaN   ...               BAG        IV
# 91756      Sulfameth/Trimethoprim DS   ...               TAB        PO
# 91757                            NaN   ...               BAG        IV
# 91758                            NaN   ...               BAG        IV
# 92193                            NaN   ...               BAG        IV
# 92194                            NaN   ...               BAG        IV
# 92195                            NaN   ...               BAG        IV
# 92196                            NaN   ...              VIAL        IV
# 92197                            NaN   ...              VIAL        IV
# 92198                            NaN   ...               BAG        IV
# 93674      Sulfameth/Trimethoprim SS   ...               TAB        PO
# 93867      Sulfameth/Trimethoprim SS   ...               TAB        PO
# 94379                            NaN   ...               BAG        IV
# 94380                    Clindamycin   ...               CAP        PO
#
#          rxcui Antibiotics        dob gender     first_admittime  \
# 1493   1807508        True 2111-07-17      M 2163-09-06 16:20:00
# 1494   1807516        True 2111-07-17      M 2163-09-06 16:20:00
# 1721   1366116        True 2166-07-13      M 2201-01-21 05:52:00
# 2019    308460        True 2078-04-30      F 2143-06-26 08:00:00
# 2601   1807508        True 2105-12-15      F 2179-08-17 14:41:00
# 92194  1807508        True 2057-01-10      M 2115-06-29 00:03:00
# 92195  1807508        True 2057-01-10      M 2115-06-29 00:03:00
# 92196  1807516        True 2057-01-10      M 2115-06-29 00:03:00
# 92197  1807516        True 2057-01-10      M 2115-06-29 00:03:00
# 92198  1807508        True 2057-01-10      M 2115-06-29 00:03:00
# 93674   198334        True 2088-06-14      M 2155-08-04 10:30:00
# 93867   198334        True 2087-08-12      M 2148-03-15 17:33:00
# 94379  1807508        True 2127-08-08      M 2192-12-11 11:43:00
# 94380   197518        True 2127-08-08      M 2192-12-11 11:43:00
#
#       first_admit_age    dbsource pt_ab_db
# 1493            52.14  metavision    mv_ab
# 1494            52.14  metavision    mv_ab
# 1721            34.53  metavision    mv_ab
# 2019            65.15  metavision    mv_ab
# 2601            73.67  metavision    mv_ab
# 2602            73.67  metavision    mv_ab
# 2603            73.67  metavision    mv_ab
# 2604            73.67  metavision    mv_ab
# 2605            73.67  metavision    mv_ab
# 2606            73.67  metavision    mv_ab
# 2607            73.67  metavision    mv_ab
# 2896            71.17  metavision    mv_ab
# 2897            71.17  metavision    mv_ab
# 2929            61.10  metavision    mv_ab
# 3016            52.12  metavision    mv_ab
# 3183            67.21  metavision    mv_ab
# 4657            84.40  metavision    mv_ab
# 4658            84.40  metavision    mv_ab
# 5073            50.42  metavision    mv_ab
# 5268            56.63  metavision    mv_ab
# 6254            73.84  metavision    mv_ab
# 8074            60.17  metavision    mv_ab
# 8479            87.21  metavision    mv_ab
# 8480            87.21  metavision    mv_ab
# 9065            76.27  metavision    mv_ab
# 9066            76.27  metavision    mv_ab
# 9067            76.27  metavision    mv_ab
# 9122            54.70  metavision    mv_ab
# 9123            54.70  metavision    mv_ab
# 9124            54.70  metavision    mv_ab
# ...               ...         ...      ...
# 86834           59.56  metavision    mv_ab
# 86835           59.56  metavision    mv_ab
# 87294           59.81  metavision    mv_ab
# 88591           62.29  metavision    mv_ab
# 88592           62.29  metavision    mv_ab
# 89402           82.24  metavision    mv_ab
# 89404           66.84  metavision    mv_ab
# 89405           66.84  metavision    mv_ab
# 89479           57.74  metavision    mv_ab
# 89480           57.74  metavision    mv_ab
# 89879           62.53  metavision    mv_ab
# 89880           62.53  metavision    mv_ab
# 90385          300.00  metavision    mv_ab
# 91482           48.24  metavision    mv_ab
# 91483           48.24  metavision    mv_ab
# 91484           48.24  metavision    mv_ab
# 91485           48.24  metavision    mv_ab
# 91756           26.47  metavision    mv_ab
# 91757           43.41  metavision    mv_ab
# 91758           43.41  metavision    mv_ab
# 92193           58.46  metavision    mv_ab
# 92194           58.46  metavision    mv_ab
# 92195           58.46  metavision    mv_ab
# 92196           58.46  metavision    mv_ab
# 92197           58.46  metavision    mv_ab
# 92198           58.46  metavision    mv_ab
# 93674           67.14  metavision    mv_ab
# 93867           60.59  metavision    mv_ab
# 94379           65.35  metavision    mv_ab
# 94380           65.35  metavision    mv_ab
#
# [1239 rows x 27 columns]

# %%
ABrx_merged_16sterile_ntnul_pts.loc[ABrx_merged_16sterile_ntnul_pts.loc[:,'subject_id'].isin(pt_not_captured_in_event),:]['pt_ab_db'].value_counts()
#breakdown of db source for pt with ab who i didn't capture in my algorithm.
# Out:
# cv_ab              4036
# mv_ab               649
# cv/mv_ab             32
# both_marking_ab      11
# Name: pt_ab_db, dtype: int64

# %% [markdown]
# summary:
# subject_id: 24942
# label: vancomycin HCL
# datasource: cv
# Hadm_id:    178112
# starttime 2159-11-08
# I cant find any record of vancomycin perscribed to this pt
#
#
# subject_id: 24656
# hadm_id: 157923
# icustay_id: 235199
# label: vancomysin
#
# prescription table lists vancomysin being prescribed on 2167-12-19, with the same enddate. was admitted 2167-10-19
#
# chart says (under chemistry, which is odd):
# [**2167-12-19**] 07:40AM    1.5
# ADDED ON @ 1045AM
# ANTIBIOTICS Vanco
#
# other part of note says: Patient with febrile neutropenia(drops counts on
# immunosuppression), received 1 dose of neupogen and 4 days of
# vanc/ceftaz
# Patient defervesed but no source was idenitified.
# CMV VL neg and EBV VL pending upon discharge. Blood, urine
# cultures with no growth.
#
#
# OHHHh this patient was likely not in the icu anymore when rx antibiotics. they were discharged from the icu on 2167-12-18, but form hospital on 12-23. looks like they transfered her from operating room to ICU .
#
# On postoperative day seven the patient began to complain of
# increasing nausea as well as diarrhea.  Stools were sent at
# that time for C.  diff and she was begun on empiric Flagyl.
# The following morning the patient had a white count of
# 34,000.  She was pan cultured and had abdominal films done at
# that time.  General surgery was consulted.  The General
# surgery service felt the patient had a toxic megacolon.  She
# was brought to the Operating Room where she underwent a
# partial colectomy with ileostomy and as well as a
# cholecystectomy, following which the patient was transferred
# back to the Cardiothoracic Intensive Care Unit..
#
# She
# spent four days in the Intensive Care Unit following her
# abdominal surgery, and was then transferred to the floor for
# continuing postoperative care.
#
#
# **** overall this is a very confusing case where there is contradictory info or important date info omitted throughout their chart. it seems like they may have been transfered to the icu. the vancomysin sounds like it was an older prescription for his surgery, which occured before 2167, whereas the 2167 visit was due to diabetes and had no signs of infecton or rx of antibiotic rx. This patient shouldn't be included
#
#
#
# summary:
# subject_id: 26027
# label: Bacitracin Ointment  !!!topical antibiotic, not useful for this study.
# datasource: mv
# Hadm_id:    159497
#
# *** do not include
#
# summary:
# subject_id: 26220
# label: Azithromycin
# datasource: mv
# Hadm_id:    196422
# icustay_id: 204624
# startdate: 2150-04-12
#
# patient appears to have been given azithromycin in the icu on 04-12, however this is not listed in any chartevents or inputevents_mv so there would have been no way to capture this. confired by reading chartnote and looking at prescription table.

# %%
#summary of manual lookup of pts not captured in events or rx, 
#out of 10 manual lookups, only one of the patients (26220) had somthing that may have been usable for our study.
#the rest of them either were topical antibioitcs, came in while on antibiotics and were continued, or were potentially accidental entries.

# %%
##4/12/18:

#1) need to relook up work i did on when pt was admitted to icu, 
#and match up the first antibiotic of each kind for each patient.
-done

#2) compare time between first antiboitic time in event table and start time in prescription table. 


#3) write script to count consecutive ab of anytype for each event pt

#4) patient selection: do patients have sterile culture within 24 hour of their first ab dose?
    #a) first identify first antibiotic date associated with the antiboitic hadm id's

# %% [markdown]
# # after all reinitialized this is where to start out again

# %%
#this cell should be obsolete now, after my fortifying of the cohort generation notebook

# #ABrx_merged_16sterile_ntnul = pd.merge(ABrx_merged_16sterile_ntnul, testframe, left_on= 'hadm_id', right_on='hadm_id', how = 'inner')

# set(list(sterile_pt_df3)).intersection(set(list(ABrx_merged_16sterile_ntnul))) #hadm, row_id, subject_id
# set(list(sterile_pt_df3)).intersection(set(list(final_events_df)))# charttime, hadm, row_id, subject_id


# ABrx_merged_16sterile_ntnul = pd.merge(ABrx_merged_16sterile_ntnul, sterile_pt_df3, left_on= 'hadm_id', right_on='hadm_id', how = 'left')

# #these 2 lines should be obsolete now, after my fortifying of the cohort generation notebook

# #final_events_df = pd.merge(final_events_df, sterile_pt_df2[['hadm_id','first_sterile_date','hadm_dates_range', 'culture_count']], left_on= 'hadm_id', right_on='hadm_id', how = 'left')
# #ABrx_merged_16sterile_ntnul = pd.merge(ABrx_merged_16sterile_ntnul, sterile_pt_df2[['hadm_id','first_sterile_date','hadm_dates_range', 'culture_count']], left_on= 'hadm_id', right_on='hadm_id', how = 'left')
# Out:
# {'charttime', 'hadm_id', 'row_id', 'subject_id'}
# time: 3.72 ms

# %%
# #run after annotating time delta on ABrx for first sterile date per hadm_id on event and rx.
# pd.DataFrame(final_events_df).to_csv('final_events_df_04-16-18.csv')
# pd.DataFrame(ABrx_merged_16sterile_ntnul).to_csv('ABrx_merged_16sterile_ntnul_04-16-18.csv')

# %%
#2- compare time between rx and events lists


#final_overlap_pts = final patients in both datasets. who are 16yo+, have sterile cultures associated with antiboitics (hadm_id).



#final_events_pt_list= list(final_events_df.loc[final_events_df.loc[:,'first_ab_date']!= 0, "subject_id"].unique())
final_events_pt_list = list(final_events_df['subject_id'].unique())
final_abrx_pt_list = list(ABrx_merged_16sterile_ntnul['subject_id'].unique())

#final_overlap_pts = [x for x in (final_events_pt_list and final_abrx_pt_list)]
final_overlap_pts= set(final_events_pt_list).intersection(set(final_abrx_pt_list))
print(len(final_overlap_pts)) #11735 patients that overlap between Rx and events

#random sample to compare. 
random_overlap_pts = list(random.sample(final_overlap_pts, 20)) #went from ~11,000 to 12,455 after adding in new rx rows.
# Out:
# 9984
# time: 13.4 ms

# %%
event_rnd=final_events_df.loc[final_events_df.loc[:,'subject_id'].isin(random_overlap_pts), :].sort_values(by=['subject_id','charttime'])
#event_rnd
event_rnd.loc[event_rnd.loc[:,"subject_id"]==8532,:]
# Out:
#         row_id  subject_id            charttime  itemid  icustay_id  hadm_id  \
# 11018  1217629        8532  2129-12-25 14:28:00  225884    282142.0   156020
# 11019  1217642        8532  2129-12-25 16:26:00  225798    282142.0   156020
# 11020  1217619        8532  2129-12-25 20:23:00  225798    282142.0   156020
# 11021  1217608        8532  2129-12-25 21:48:00  225884    282142.0   156020
# 11022  1529767        8532  2130-05-07 08:14:00  225798    211727.0   153370
# 11023  1529752        8532  2130-05-07 14:21:00  225855    211727.0   153370
# 11024  1529754        8532  2130-05-07 20:07:00  225798    211727.0   153370
# 11025  1529756        8532  2130-05-08 08:36:00  225798    211727.0   153370
# 97478  185952        8532   122585     214991  2131-04-02  2131-04-06
# 97479  186120        8532   122585     214991  2131-04-04  2131-04-05
#
#       drug_type                    drug           drug_name_poe  \
# 97472      MAIN          Vancomycin HCl                     NaN
# 97480      MAIN  MetRONIDAZOLE (FLagyl)                     NaN
# 97481      MAIN  MetRONIDAZOLE (FLagyl)  MetRONIDAZOLE (FLagyl)
# 97474      MAIN            Levofloxacin            Levofloxacin
# 97475      MAIN              Vancomycin                     NaN
# 97476      MAIN             CeftriaXONE                     NaN
# 97473      MAIN            Levofloxacin            Levofloxacin
# 97477      MAIN              Vancomycin                     NaN
# 97478      MAIN            Levofloxacin            Levofloxacin
# 97479      MAIN              Vancomycin                     NaN
#
#             drug_name_generic         ...           route    rxcui  \
# 97472                     NaN         ...              IV      NaN
# 97480                     NaN         ...              IV   311683
# 97481  MetRONIDAZOLE (FLagyl)         ...           PO/NG      NaN
# 97474            Levofloxacin         ...           PO/NG      NaN
# 97475                     NaN         ...              IV  1807516
# 97476                     NaN         ...              IV  1665021
# 97473            Levofloxacin         ...           PO/NG      NaN
# 97477                     NaN         ...              IV  1807508
# 97478            Levofloxacin         ...              PO   211815
# 97479                     NaN         ...              IV  1807508
#
#        Antibiotics        dob gender     first_admittime first_admit_age  \
# 97472        False 1823-07-20      F 2123-07-20 16:48:00           300.0
# 97480         True 1823-07-20      F 2123-07-20 16:48:00           300.0
# 97481        False 1823-07-20      F 2123-07-20 16:48:00           300.0
# 97474        False 1823-07-20      F 2123-07-20 16:48:00           300.0
# 97475         True 1823-07-20      F 2123-07-20 16:48:00           300.0
# 97476         True 1823-07-20      F 2123-07-20 16:48:00           300.0
# 97473        False 1823-07-20      F 2123-07-20 16:48:00           300.0
# 97477         True 1823-07-20      F 2123-07-20 16:48:00           300.0
# 97478         True 1823-07-20      F 2123-07-20 16:48:00           300.0
# 97479         True 1823-07-20      F 2123-07-20 16:48:00           300.0
#
#          dbsource  pt_ab_db   first_sterile_date
# 97472     carevue  cv/mv_ab  2123-07-28 18:00:00
# 97480  metavision  cv/mv_ab  2123-07-28 18:00:00
# 97481  metavision  cv/mv_ab  2123-07-28 18:00:00
# 97474  metavision  cv/mv_ab  2123-07-28 18:00:00
# 97475  metavision  cv/mv_ab  2123-07-28 18:00:00
# 97476  metavision  cv/mv_ab  2123-07-28 18:00:00
# 97473  metavision  cv/mv_ab  2123-07-28 18:00:00
# 97477  metavision  cv/mv_ab  2123-07-28 18:00:00
# 97478  metavision  cv/mv_ab  2123-07-28 18:00:00
# 97479  metavision  cv/mv_ab  2123-07-28 18:00:00
#
# [10 rows x 28 columns]

# %%
compare_table=0
compare_table = pd.DataFrame({
    'subject_id': []
    ,'first date in rx': [],
    'ab name in rx': [],
    'first date in event': [],
     'ab name in event': [],
     'date delta': []}, columns=[
    'subject_id','first date in rx', 'ab name in rx','first date in event','ab name in event','date delta'])

compare_table['subject_id']= list(final_overlap_pts)
#random_overlap_pts
#final_overlap_pts
# Out:
# time: 11.1 ms

# %%
len(final_overlap_pts)
# Out:
# 9984
# time: 1.66 ms

# %%
#try to populate table

for element in list(compare_table['subject_id']):
    compare_table.loc[compare_table.loc[:,'subject_id']==element,'first date in event'] = min(final_events_df.loc[final_events_df.loc[:,'subject_id']==element, :]['charttime'])
    compare_table.loc[compare_table.loc[:,'subject_id']==element,'first date in rx'] = min(ABrx_merged_16sterile_ntnul.loc[ABrx_merged_16sterile_ntnul.loc[:,'subject_id']==element, :]['startdate'])
    compare_table.loc[compare_table.loc[:,'subject_id']==element,'ab name in event'] = min(final_events_df.loc[final_events_df.loc[:,'subject_id']==element, :]['label'])
    compare_table.loc[compare_table.loc[:,'subject_id']==element,'ab name in rx'] = min(ABrx_merged_16sterile_ntnul.loc[ABrx_merged_16sterile_ntnul.loc[:,'subject_id']==element, :]['drug'])
# Out:
# time: 2min 19s

# %%
compare_table.head()

compare_table['first date in event'] = pd.to_datetime(compare_table['first date in event'])
compare_table['first date in event'] = compare_table['first date in event'].dt.strftime('%Y-%m-%d 00:00:00')
compare_table['first date in event'] = pd.to_datetime(compare_table['first date in event'])


compare_table['first date in rx'] = pd.to_datetime(compare_table['first date in rx'])
compare_table['first date in rx']= compare_table['first date in rx'].dt.strftime('%Y-%m-%d 00:00:00')
compare_table['first date in rx'] = pd.to_datetime(compare_table['first date in rx'])

compare_table.head()

compare_table2= compare_table

compare_table2['date delta']= compare_table2['first date in rx']-compare_table2['first date in event']
# Out:
# time: 16.7 ms

# %%
compare_table2
# Out:
#     subject_id first date in rx               ab name in rx  \
# 0        85535       2197-01-30                   CefazoLIN
# 1         1293       2127-07-10              Vancomycin HCl
# 2        74253       2194-12-22                    CefePIME
# 3         9736       2190-04-11                   CefazoLIN
# 4        13558       2141-02-16           Ampicillin Sodium
# 5        72202       2187-12-18                   CefazoLIN
# 6        24477       2195-10-20           Ciprofloxacin HCl
# 7        27742       2126-11-22  Piperacillin-Tazobactam Na
# 8        50832       2118-09-05                 CeftriaXONE
# 9        23473       2151-03-25                   Nafcillin
# 10       46608       2199-03-26                  Vancomycin
# 11       23811       2145-07-25                Levofloxacin
# 12       59266       2120-09-05        Ampicillin-Sulbactam
# 13       83981       2109-08-22               Azithromycin
# 14       44653       2133-07-19           Ciprofloxacin HCl
# 15       98494       2147-04-18                   Meropenem
# 16       90155       2122-01-15                Azithromycin
# 17        4685       2121-02-20                Azithromycin
# 18       87206       2149-02-16                Azithromycin
# 19       89402       2173-02-24                  Vancomycin
#
#    first date in event   ab name in event date delta
# 0           2197-01-30          Cefazolin     0 days
# 1           2127-07-10  Vancomycin/Random     0 days
# 2           2194-12-22         Ampicillin     0 days
# 3           2190-04-17  Vancomycin/Random    -6 days
# 4           2141-02-17  Vancomycin/Random    -1 days
# 5           2187-12-18          Cefazolin     0 days
# 6           2195-10-19          Cefazolin     1 days
# 7           2126-11-23  Vancomycin/Random    -1 days
# 8           2118-09-04       Azithromycin     1 days
# 9           2151-03-24  Vancomycin/Random     1 days
# 10          2199-03-27         Vancomycin    -1 days
# 11          2145-08-14  Vancomycin/Random   -20 days
# 12          2120-09-05         Ampicillin     0 days
# 13          2109-08-22       Azithromycin     0 days
# 14          2133-07-19      Ciprofloxacin     0 days
# 15          2144-09-13      Ciprofloxacin   947 days
# 16          2122-01-16       Azithromycin    -1 days
# 17          2121-02-22  Vancomycin/Random    -2 days
# 18          2149-02-15       Azithromycin     1 days
# 19          2173-02-25         Vancomycin    -1 days
# time: 13.6 ms

# %%
compare_table['first date in event'] = pd.to_datetime(compare_table['first date in event'])
#compare_table['first date in event'] = compare_table['first date in event'].dt.strftime('%Y-%m-%d')

compare_table['first date in rx'] = pd.to_datetime(compare_table['first date in rx'])
#compare_table['first date in rx']= compare_table['first date in rx'].dt.strftime('%Y-%m-%d')

#compare_table['date delta']= compare_table['first date in rx'].tolist() - compare_table['first date in event'].tolist()
#df_test['Difference'] = df_test['First_Date'].sub(df_test['Second Date'], axis=0)
#compare_table['date delta'] = compare_table['first date in rx'].sub(compare_table['first date in event'], axis=0)
#compare_table['first date in event'].dt.strftime('%Y-%m-%d')

for element in range(len(compare_table)):
    compare_table.iloc[element,5]= pd.Timedelta(compare_table.iloc[element,1]-compare_table.iloc[element,3], unit='d')
    #print(element)
compare_table

#subject 20236 and 15644 suggest that the hadm id isnt conserved over every one.
# Out:
#     subject_id first date in rx                  ab name in rx  \
# 0        51586       2132-09-18                   Levofloxacin
# 1         5729       2102-03-11                   Levofloxacin
# 2        61735       2180-10-31                  Azithromycin
# 3         8532       2123-07-22                    CeftriaXONE
# 4        10941       2126-06-21                    Ceftazidime
# 5        46228       2183-11-27    Amoxicillin-Clavulanic Acid
# 6        47460       2172-08-01                      CefazoLIN
# 7        95208       2123-10-19              Ciprofloxacin HCl
# 8        25111       2147-01-07                   Levofloxacin
# 9        56634       2105-12-17                       CefePIME
# 10       28318       2119-09-26                   Levofloxacin
# 11       75029       2199-05-21                      CefazoLIN
# 12       58781       2161-09-05              Ampicillin Sodium
# 13       86888       2157-08-17                     Vancomycin
# 14       47087       2105-02-10                      CefazoLIN
# 15       95160       2102-02-21                      CefazoLIN
# 16       31770       2152-11-03          *NF* Ertapenem Sodium
# 17       44787       2122-04-24  Amoxicillin-Clavulanate Susp.
# 18        1541       2104-08-18                   Levofloxacin
# 19        8493       2130-05-09                   Levofloxacin
#
#    first date in event               ab name in event            date delta
# 0  2132-09-18 08:00:00                   Levofloxacin     -1 days +16:00:00
# 1  2102-03-12 19:54:00              Vancomycin/Random     -2 days +04:06:00
# 2  2180-10-31 13:30:00                   Azithromycin     -1 days +10:30:00
# 3  2129-12-25 14:28:00                    Ceftriaxone  -2349 days +09:32:00
# 4  2126-06-23 05:27:00              Vancomycin/Random     -3 days +18:33:00
# 5  2183-11-27 19:19:00                    Ceftriaxone     -1 days +04:41:00
# 6  2172-08-01 14:59:00                      Cefazolin     -1 days +09:01:00
# 7  2123-10-18 22:43:00              Bactrim (SMX/TMP)       0 days 01:17:00
# 8  2148-04-10 10:00:00              Vancomycin/Random   -460 days +14:00:00
# 9  2105-12-07 22:10:00                      Cefazolin       9 days 01:50:00
# 25479    Cefepime  2136-05-16 06:10:00
# 25480  Vancomycin  2136-05-16 06:10:00
# 25481    Cefepime  2136-05-16 06:10:00
# 25482  Vancomycin  2136-05-16 06:10:00

# %%
ABrx_merged_16sterile_ntnul.loc[ABrx_merged_16sterile_ntnul.loc[:,'subject_id']==20236,:].sort_values('startdate').head()
# Out:
#         row_id  subject_id  hadm_id icustay_id   startdate     enddate  \
# 92249  2789778       20236   154430     241146  2130-09-03  2130-09-08
# 92250  2789762       20236   154430     241146  2130-09-03  2130-09-04
# 92237  2791202       20236   151904     295481  2136-05-16  2136-05-18
# 92238  2791212       20236   151904     295481  2136-05-17  2136-05-18
# 92239  2791213       20236   151904     295481  2136-05-17  2136-05-19
#
#       drug_type                 drug        drug_name_poe  \
# 92249      MAIN  Bacitracin Ointment  Bacitracin Ointment
# 92250      MAIN            CefazoLIN                  NaN
# 92237      MAIN             CefePIME                  NaN
# 92238      MAIN           Vancomycin                  NaN
# 92239      MAIN           Vancomycin                  NaN
#
#          drug_name_generic    ...    form_unit_disp route    rxcui  \
# 92249  Bacitracin Ointment    ...              TUBE    TP  1366116
# 92250                  NaN    ...               BAG    IV  1665050
# 92237                  NaN    ...                mL    IV  1665093
# 92238                  NaN    ...               BAG    IV  1807508
# 92239                  NaN    ...               BAG    IV  1807508
#
#       Antibiotics        dob gender     first_admittime first_admit_age  \
# 92249        True 2090-05-12      M 2130-09-02 21:45:00           40.31
# 92250        True 2090-05-12      M 2130-09-02 21:45:00           40.31
# 92237        True 2090-05-12      M 2130-09-02 21:45:00           40.31
# 92238        True 2090-05-12      M 2130-09-02 21:45:00           40.31
# 92239        True 2090-05-12      M 2130-09-02 21:45:00           40.31
#
#          dbsource  pt_ab_db
# 92249     carevue  cv/mv_ab
# 92250     carevue  cv/mv_ab
# 92237  metavision  cv/mv_ab
# 92238  metavision  cv/mv_ab
# 92239  metavision  cv/mv_ab
#
# [5 rows x 27 columns]

# %%
compare_table['first date in rx'] = min(
    final_events_df.loc[final_events_df.loc[:,'subject_id'].isin(random_overlap_pts), :].sort_values(by=['subject_id','charttime'])['charttime'])

compare_table

# %%
compare_table
# Out:
#     subject_id first date in rx                  ab name in rx  \
# 0        51586       2132-09-18                   Levofloxacin
# 1         5729       2102-03-11                   Levofloxacin
# 2        61735       2180-10-31                  Azithromycin
# 3         8532       2123-07-22                    CeftriaXONE
# 4        10941       2126-06-21                    Ceftazidime
# 5        46228       2183-11-27    Amoxicillin-Clavulanic Acid
# 6        47460       2172-08-01                      CefazoLIN
# 7        95208       2123-10-19              Ciprofloxacin HCl
# 8        25111       2147-01-07                   Levofloxacin
# 9        56634       2105-12-17                       CefePIME
# 10       28318       2119-09-26                   Levofloxacin
# 11       75029       2199-05-21                      CefazoLIN
# 12       58781       2161-09-05              Ampicillin Sodium
# 13       86888       2157-08-17                     Vancomycin
# 14       47087       2105-02-10                      CefazoLIN
# 15       95160       2102-02-21                      CefazoLIN
# 16       31770       2152-11-03          *NF* Ertapenem Sodium
# 17       44787       2122-04-24  Amoxicillin-Clavulanate Susp.
# 18        1541       2104-08-18                   Levofloxacin
# 19        8493       2130-05-09                   Levofloxacin
#
#    first date in event               ab name in event            date delta
# 0  2132-09-18 08:00:00                   Levofloxacin     -1 days +16:00:00
# 1  2102-03-12 19:54:00              Vancomycin/Random     -2 days +04:06:00
# 2  2180-10-31 13:30:00                   Azithromycin     -1 days +10:30:00
# 3  2129-12-25 14:28:00                    Ceftriaxone  -2349 days +09:32:00
# 4  2126-06-23 05:27:00              Vancomycin/Random     -3 days +18:33:00
# 5  2183-11-27 19:19:00                    Ceftriaxone     -1 days +04:41:00
# 6  2172-08-01 14:59:00                      Cefazolin     -1 days +09:01:00
# 7  2123-10-18 22:43:00              Bactrim (SMX/TMP)       0 days 01:17:00
# 8  2148-04-10 10:00:00              Vancomycin/Random   -460 days +14:00:00
# 9  2105-12-07 22:10:00                      Cefazolin       9 days 01:50:00
# 10 2119-09-23 13:08:00              Vancomycin/Random       2 days 10:52:00
# 11 2199-05-22 01:45:00                      Cefazolin     -2 days +22:15:00
# 12 2167-01-09 22:21:00                     Ampicillin  -1953 days +01:39:00
# 13 2157-08-17 21:00:00                     Vancomycin     -1 days +03:00:00
# 14 2105-02-10 21:00:00                      Cefazolin     -1 days +03:00:00
# 15 2102-02-21 20:00:00                      Cefazolin     -1 days +04:00:00
# 16 2153-02-27 05:00:00            Vancomycin (Random)   -117 days +19:00:00
# 17 2122-04-22 12:00:00  Ampicillin/Sulbactam (Unasyn)       1 days 12:00:00
# 18 2104-08-17 08:35:00              Vancomycin/Random       0 days 15:25:00
# 19 2130-05-10 02:56:00              Vancomycin/Random     -2 days +21:04:00

# %% [markdown]
# TODO on weekend/monday:  04/13/18:
#
# redo compare table with hadm_id that are overlapped. for the x # of hadm_id that are overlapped we should make a table that looks at the time differential between rx and events. my current table doesn't just look at hadm_id, it looks at first for each pt, which can be conflicting. there are many instances where the chartevents/inputevents tables don't have any mention of ab.
#
# also should do the same thing but for just rx table and compare the delta between the first sterile culture time and the start time.

# %%
#making an Rxcui and Prescription table that overlap with icustay_id.  

#len(set(fst).intersection(snd))
hadm_overlap= list(set(list(final_events_df['hadm_id'].unique())).intersection( set(list(ABrx_merged_16sterile_ntnul['hadm_id'].unique()))))
final_events_df_hadmoverlap= final_events_df.loc[final_events_df.loc[:,'hadm_id'].isin(hadm_overlap),:]
ABrx_merged_16sterile_ntnul_hadmoverlap= ABrx_merged_16sterile_ntnul.loc[ABrx_merged_16sterile_ntnul.loc[:,'hadm_id'].isin(hadm_overlap),:]



random_overlap_pts = list(random.sample(list(ABrx_merged_16sterile_ntnul_hadmoverlap['subject_id'].unique()), 20)) #N=20
total_overlap_pts= list(ABrx_merged_16sterile_ntnul_hadmoverlap['subject_id'].unique()) #N=12327

# %%
print(len(ABrx_merged_16sterile_ntnul['hadm_id'].unique()), #25761 icu stays, 24039 hadm_id
len(final_events_df['hadm_id'].unique()))  #17814 icu stays, 16738 hadm_id
# Out:
# 24039 16738

# %%
print(len(ABrx_merged_16sterile_ntnul_hadmoverlap['hadm_id'].unique()), #25761 icu stays, 24039 hadm_id
len(final_events_df_hadmoverlap['hadm_id'].unique()))  #17814 icu stays, 16738 hadm_id
#both have 14727 hadm_id.
# Out:
# 14727 14727

# %%
len(total_overlap_pts) #12327
# Out:
#     row_id  subject_id  hadm_id  icustay_id  startdate     enddate drug_type  \
# 0  2366833       24915   194424    267059.0 2182-12-10  2182-12-10      MAIN
# 1  2366088       24915   194424    267059.0 2182-11-29  2182-12-24      MAIN
# 2  2366064       24915   194424    267059.0 2182-11-17  2182-11-20      MAIN
# 3  2366065       24915   194424    267059.0 2182-11-17  2182-11-29      MAIN
# 4  2367574       24915   194424    267059.0 2183-01-12  2183-01-15      MAIN
#
#                   drug drug_name_poe drug_name_generic  \
# 0           Daptomycin           NaN               NaN
# 1  Imipenem-Cilastatin           NaN               NaN
# 2       Vancomycin HCl           NaN               NaN
# 3  Imipenem-Cilastatin           NaN               NaN
# 4         Levofloxacin           NaN               NaN
#
#             ...                 rxcui  Antibiotics         dob gender  \
# 0           ...              404652.0         True  2129-04-20      F
# 1           ...             1726216.0         True  2129-04-20      F
# 2           ...              239209.0         True  2129-04-20      F
# 3           ...             1726216.0         True  2129-04-20      F
# 4           ...                   NaN        False  2129-04-20      F
#
#        first_admittime first_admit_age dbsource pt_ab_db  first_sterile_date  \
# 0  2182-11-11 20:01:00           53.56  carevue    cv_ab 2182-11-12 01:50:00
# 1  2182-11-11 20:01:00           53.56  carevue    cv_ab 2182-11-12 01:50:00
# 2  2182-11-11 20:01:00           53.56  carevue    cv_ab 2182-11-12 01:50:00
# 3  2182-11-11 20:01:00           53.56  carevue    cv_ab 2182-11-12 01:50:00
# 4  2182-11-11 20:01:00           53.56  carevue    cv_ab 2182-11-12 01:50:00
#
#    culture_starttime_delta
# 0         27 days 22:10:00
# 1         16 days 22:10:00
# 2          4 days 22:10:00
# 3          4 days 22:10:00
# 4         60 days 22:10:00
#
# [5 rows x 29 columns]

# %%
compare_table=0
compare_table = pd.DataFrame({
    'subject_id': []
    ,'first date in rx': [],
    'ab name in rx': [],
    'first date in event': [],
     'ab name in event': [],
    'hadm_id': [],
     'date delta': []}, columns=[
    'subject_id','first date in rx', 'ab name in rx','first date in event','ab name in event','date delta'])

#compare_table['subject_id']= total_overlap_pts
compare_table['hadm_id']= final_events_df_hadmoverlap['hadm_id'].unique()

# %%
#try to populate table

#would be nice to vectorize this

#change this for in list hadm_id and list the subject_id

#changed 'subject_id' everywhere to 'hadm_id'

for element in list(compare_table['hadm_id']):
    compare_table.loc[compare_table.loc[:,'hadm_id']==element,'first date in event'] = min(final_events_df_hadmoverlap.loc[final_events_df_hadmoverlap.loc[:,'hadm_id']==element, :]['charttime'])
    compare_table.loc[compare_table.loc[:,'hadm_id']==element,'first date in rx'] = min(ABrx_merged_16sterile_ntnul_hadmoverlap.loc[ABrx_merged_16sterile_ntnul_hadmoverlap.loc[:,'hadm_id']==element, :]['startdate'])
    compare_table.loc[compare_table.loc[:,'hadm_id']==element,'ab name in event'] = min(final_events_df_hadmoverlap.loc[final_events_df_hadmoverlap.loc[:,'hadm_id']==element, :]['label'])
    compare_table.loc[compare_table.loc[:,'hadm_id']==element,'ab name in rx'] = min(ABrx_merged_16sterile_ntnul_hadmoverlap.loc[ABrx_merged_16sterile_ntnul_hadmoverlap.loc[:,'hadm_id']==element, :]['drug'])
    compare_table.loc[compare_table.loc[:,'hadm_id']==element,'subject_id'] = ABrx_merged_16sterile_ntnul_hadmoverlap.loc[ABrx_merged_16sterile_ntnul_hadmoverlap.loc[:,'hadm_id']==element, :]['subject_id'].unique()
    compare_table.loc[compare_table.loc[:,'subject_id']==element,'hadm_id_event'] = min(final_events_df_hadmoverlap.loc[final_events_df_hadmoverlap.loc[:,'subject_id']==element, :]['hadm_id'])
    #compare_table.loc[compare_table.loc[:,'subject_id']==element,'hadm_id_rx'] = min(ABrx_merged_16sterile_ntnul_hadmoverlap.loc[ABrx_merged_16sterile_ntnul_hadmoverlap.loc[:,'subject_id']==element, :]['hadm_id']

# %%
compare_table['first date in event'] = pd.to_datetime(compare_table['first date in event'])
#compare_table['first date in event'] = compare_table['first date in event'].dt.strftime('%Y-%m-%d')

compare_table['first date in rx'] = pd.to_datetime(compare_table['first date in rx'])
#compare_table['first date in rx']= compare_table['first date in rx'].dt.strftime('%Y-%m-%d')

#compare_table['date delta']= compare_table['first date in rx'].tolist() - compare_table['first date in event'].tolist()
#df_test['Difference'] = df_test['First_Date'].sub(df_test['Second Date'], axis=0)
#compare_table['date delta'] = compare_table['first date in rx'].sub(compare_table['first date in event'], axis=0)
#compare_table['first date in event'].dt.strftime('%Y-%m-%d')

for element in range(len(compare_table)):
    compare_table.iloc[element,5]= pd.Timedelta(compare_table.iloc[element,1]-compare_table.iloc[element,3], unit='d')
    #print(element)
compare_table

#subject 20236 and 15644 suggest that the hadm id isnt conserved over every one.
#12327 rows for 12327 overlap patients.
# Out:
#        subject_id first date in rx                ab name in rx  \
# 0           24915       2182-11-12                Azithromycin
# 1           24922       2164-11-06                     Cefepime
# 2           24776       2154-11-11                  CeftriaXONE
# 3           24824       2120-05-24                 Levofloxacin
# 4           24837       2166-04-13                   Ampicillin
# 5           24785       2167-09-27  Amoxicillin-Clavulanic Acid
# 6           24799       2200-09-09                  Clindamycin
# 7           24675       2132-07-28                  Ceftriaxone
# 8           24676       2151-08-20                   Gentamicin
# 9           24846       2124-12-12         Ampicillin-Sulbactam
# 10          24808       2149-10-16                Metronidazole
# 11          24813       2181-10-13                     Cefepime
# 12          24746       2168-10-21                 Azithromycin
# 13          24810       2183-01-09                    CefazoLIN
# 14          24687       2145-12-10                     CefePIME
# 15          24174       2126-06-14                    Cefazolin
# 16          24178       2107-01-22                     Cefepime
# 17          24229       2171-04-28                  CeftriaXONE
# 18          24235       2129-12-20                 Azithromycin
# 19          24268       2114-02-27                    Cefazolin
# 20          24083       2176-04-22                    Aztreonam
# 21          24170       2141-10-23                 Azithromycin
# 22          24263       2167-08-03                     CefePIME
# 23          24172       2186-05-04            Ampicillin Sodium
# 12322 2175-11-29 06:44:00                Vancomycin/Random   -9 days +17:16:00
# 12323 2196-05-09 03:00:00                Vancomycin/Random   -1 days +21:00:00
# 12324 2199-01-30 01:18:00                Vancomycin/Random   -1 days +22:42:00
# 12325 2165-10-16 09:00:00                Vancomycin/Random   -3 days +15:00:00
# 12326 2127-01-22 11:41:00                Vancomycin/Random   -7 days +12:19:00
#
# [12327 rows x 6 columns]

# %%
##this is a roud about way but wayyyy faster and vectorizes the date deltas. i loose the by hour resolution though.

compare_table.head()

compare_table['first date in event'] = pd.to_datetime(compare_table['first date in event'])
compare_table['first date in event'] = compare_table['first date in event'].dt.strftime('%Y-%m-%d 00:00:00')
compare_table['first date in event'] = pd.to_datetime(compare_table['first date in event'])


compare_table['first date in rx'] = pd.to_datetime(compare_table['first date in rx'])
compare_table['first date in rx']= compare_table['first date in rx'].dt.strftime('%Y-%m-%d 00:00:00')
compare_table['first date in rx'] = pd.to_datetime(compare_table['first date in rx'])

compare_table.head()

compare_table2= compare_table

compare_table2['date delta']= compare_table2['first date in rx']-compare_table2['first date in event']

# %%
compare_table2
# Out:
#        subject_id first date in rx                ab name in rx  \
# 0             4.0       2191-03-16                  Clindamycin
# 1            21.0       2135-01-31                    Linezolid
# 2            36.0       2134-05-12                  CeftriaXONE
# 3            38.0       2166-08-10                 Levofloxacin
# 4            41.0       2133-01-03                  Clindamycin
# 5            68.0       2174-01-12               Vancomycin HCl
# 6            85.0       2167-07-26                 Azithromycin
# 7            96.0       2156-04-06                  Ceftazidime
# 8           109.0       2140-08-26                   Vancomycin
# 9           109.0       2141-06-11            Ciprofloxacin HCl
# 10          109.0       2141-09-11            Ciprofloxacin HCl
# 11          109.0       2141-09-21                    Aztreonam
# 12          109.0       2141-10-14       MetRONIDAZOLE (FLagyl)
# 13          109.0       2141-11-19            Ciprofloxacin HCl
# 14          109.0       2142-06-03                  CeftriaXONE
# 15          109.0       2142-07-13                 Levofloxacin
# 16          112.0       2196-09-28                     CefePIME
# 17          117.0       2133-11-21                Ciprofloxacin
# 18          124.0       2160-07-14          Doxycycline Hyclate
# 19          124.0       2166-01-10                    Linezolid
# 20          145.0       2144-03-30                 Levofloxacin
# 21          145.0       2145-02-16                 Levofloxacin
# 22          156.0       2120-05-25                 Levofloxacin
# 23          157.0       2106-06-18                 Levofloxacin
# 24          161.0       2173-06-13   Piperacillin-Tazobactam Na
# 25          164.0       2116-12-31                  Ceftazidime
# 26          165.0       2170-10-04                 Azithromycin
# 27          177.0       2125-11-12                 Levofloxacin
# 28          188.0       2160-11-26    Sulfameth/Trimethoprim SS
# 29          188.0       2161-01-01                    CefazoLIN
# ...           ...              ...                          ...
# 14697     99785.0       2122-10-08                    CefazoLIN
# 14698     99791.0       2170-04-12                    Meropenem
# 14699     99817.0       2166-10-15            Ampicillin Sodium
# 14700     99819.0       2136-03-28            Ciprofloxacin HCl
# 14701     99822.0       2197-06-16                 Azithromycin
# 14702     99822.0       2197-07-05                    Linezolid
# 14703     99830.0       2187-08-21                    CefazoLIN
# 14704     99836.0       2116-05-28                     CefePIME
# 14699          2166-10-25                       Ampicillin   -10 days   195557
# 14700          2136-03-28                       Vancomycin     0 days   126883
# 14701          2197-06-16                         Cefepime     0 days   163117
# 14702          2197-07-04                         Cefepime     1 days   195871
# 14703          2187-08-21                Bactrim (SMX/TMP)     0 days   176834
# 14704          2116-05-28                         Cefepime     0 days   101018
# 14705          2184-04-05    Ampicillin/Sulbactam (Unasyn)     0 days   197195
# 14706          2191-04-13                         Cefepime     0 days   155024
# 14707          2171-04-03                     Levofloxacin     0 days   178839
# 14708          2142-04-04                        Cefazolin     0 days   100749
# 14709          2184-12-23                     Levofloxacin     7 days   189346
# 14710          2103-12-20                        Cefazolin     0 days   143544
# 14711          2174-01-21                         Cefepime     0 days   172327
# 14712          2132-09-16                       Vancomycin     0 days   198523
# 14713          2129-07-05                       Ampicillin     0 days   127380
# 14714          2113-06-04                     Piperacillin     3 days   188409
# 14715          2153-04-13                         Cefepime     1 days   189380
# 14716          2141-05-12                        Cefazolin     0 days   175989
# 14717          2201-05-16    Ampicillin/Sulbactam (Unasyn)     0 days   192053
# 14718          2110-02-28              Imipenem/Cilastatin     0 days   176121
# 14719          2200-10-27                       Vancomycin     0 days   103815
# 14720          2161-02-18                         Cefepime     0 days   185654
# 14721          2139-07-15                       Ampicillin     0 days   108494
# 14722          2157-02-21                      Ceftriaxone     0 days   148574
# 14723          2180-11-27                    Metronidazole     0 days   150202
# 14724          2181-01-29                     Azithromycin     0 days   176670
# 14725          2184-12-28  Piperacillin/Tazobactam (Zosyn)     2 days   151118
# 14726          2147-02-09                        Cefazolin     0 days   137810
#
# [14727 rows x 7 columns]

# %%
compare_table2['date delta'].describe()

(compare_table2['date delta'] / pd.Timedelta(hours=1)).hist(bins = 20)#bins=xrange(min(compare_table['date delta']), 120, 1))
plt.xlabel(' rx-event time delta (days)')
plt.ylabel('# of hadm_id');

compare_table2['date delta'].describe()
# Out:
# count                       14727
# mean     -1 days +09:44:19.849256
# std        3 days 10:51:09.400299
# min            -81 days +00:00:00
# 25%               0 days 00:00:00
# 50%               0 days 00:00:00
# 75%               0 days 00:00:00
# max              34 days 00:00:00
# Name: date delta, dtype: object

# %%
compare_table['date delta'].describe()

(compare_table['date delta'] / pd.Timedelta(hours=1)).hist()#bins=xrange(min(compare_table['date delta']), 120, 1))
plt.xlabel(' rx-event time delta (hours)')
plt.ylabel('# of hadm_id');

# %%
#looking at the rows with >5 day difference.

d = timedelta(days=5)

compare_table_gr5= compare_table2.loc[compare_table2.loc[:,'date delta']>=d,:]

# 3298/14727  hadm_id have >=1 day difference. 
# 905/14727 hadm_id have >=2 day difference. 
# 425/14727 hadm_id have >=3 day difference. 
# 151/14727 hadm_id have >=5 day difference.
compare_table_gr5.head()
# Out:
#      subject_id first date in rx        ab name in rx first date in event  \
# 176      1106.0       2103-11-08         Levofloxacin          2103-11-03
# 420      2628.0       2126-01-29  Imipenem-Cilastatin          2126-01-02
# 528      3267.0       2193-08-27   Gentamicin Sulfate          2193-08-07
# 680      4113.0       2149-04-08           Vancomycin          2149-04-03
# 766      4760.0       2178-10-31       Vancomycin HCl          2178-10-24
#
#       ab name in event date delta  hadm_id
# 176       Levofloxacin     5 days   170024
# 420    Vancomycin/Peak    27 days   105769
# 528      Ciprofloxacin    20 days   134370
# 680         Vancomycin     5 days   191180
# 766  Vancomycin/Random     7 days   184259

# %% [markdown]
# Subject id: 1106
# Date delta: 5days
# Hadm_id: 170024
# First date in rx: 2103-11-08
# first date in event	2103-11-03
# first_sterile_date= 2103-11-02 14:30:00 ###this is really bizzare, how is this before icu admission?
#
# intime: 2103-11-03 13:06:03 (icustays)
# outtime: 2103-11-09 18:37:02 (icustays)
#
# it appears that the events table may have captured the antibiotics that occured during the icu stay and the Rx may have captured the AB prescription upon discharge.

# %%
final_events_df.loc[final_events_df.loc[:,'hadm_id']==170024, :]


###ok this sql code highlights that my first sterileculture algorithm is off. need to redo.
# """select * FROM mimiciii.microbiologyevents
# WHERE hadm_id =170024 AND
# NOT lower(spec_type_desc) = 'fluid received in blood culture bottles' AND
# NOT lower(spec_type_desc) = 'blood bag fluid'
# AND (lower(spec_type_desc) LIKE '%blood%' 
# OR lower(spec_type_desc) LIKE '%joint%' 
# OR lower(spec_type_desc) LIKE '%urine%' 
# OR lower(spec_type_desc) LIKE  '%csf%'
# OR lower(spec_type_desc) LIKE '%spinal%'
# OR lower(spec_type_desc) LIKE '%pleural%'
# OR lower(spec_type_desc) LIKE '%peritoneal%')
# group by subject_id, row_id
# ORDER BY count(subject_id) DESC


# """" 
#for this hadm_id it should be 2123-11-02 and it was 2103-09-27

#
# Out:
#       row_id  subject_id            charttime  itemid  icustay_id  hadm_id  \
# 1717  176467        1106  2103-11-03 20:40:00  225883    241570.0   170024
# 1718  176509        1106  2103-11-03 21:18:00  225879    241570.0   170024
# 1719  176380        1106  2103-11-04 08:00:00  225883    241570.0   170024
# 1720  176403        1106  2103-11-04 20:00:00  225883    241570.0   170024
# 1721  176462        1106  2103-11-04 20:26:00  225798    241570.0   170024
# 1722  176395        1106  2103-11-05 08:00:00  225883    241570.0   170024
# 1723  176415        1106  2103-11-05 19:00:00  225879    241570.0   170024
# 1724  176382        1106  2103-11-05 20:30:00  225883    241570.0   170024
# 1725  176474        1106  2103-11-06 08:00:00  225883    241570.0   170024
# 1726  176582        1106  2103-11-06 20:33:00  225883    241570.0   170024
# 1727  176537        1106  2103-11-07 08:02:00  225883    241570.0   170024
# 1728  176417        1106  2103-11-07 19:57:00  225883    241570.0   170024
# 1729  176552        1106  2103-11-08 07:51:00  225883    241570.0   170024
# 1730  176571        1106  2103-11-08 20:00:00  225883    241570.0   170024
# 1731  176459        1106  2103-11-09 07:30:00  225883    241570.0   170024
#
#                 storetime  cgid value  valuenum              endtime  \
# 1717  2103-11-03 20:40:00   NaN   NaN       NaN  2103-11-03 20:41:00
# 1718  2103-11-03 21:18:00   NaN   NaN       NaN  2103-11-03 21:19:00
# 1719  2103-11-04 09:44:00   NaN   NaN       NaN  2103-11-04 08:01:00
# 1720  2103-11-04 19:34:00   NaN   NaN       NaN  2103-11-04 20:01:00
# 82975      MAIN    Vancomycin           NaN               NaN
# 82976      MAIN  Levofloxacin  Levofloxacin      Levofloxacin
#
#               ...               rxcui  Antibiotics         dob gender  \
# 82975         ...           1807508.0         True  2058-07-04      M
# 82976         ...                 NaN        False  2058-07-04      M
#
#            first_admittime first_admit_age    dbsource pt_ab_db  \
# 82975  2103-09-27 18:02:00           45.23  metavision    mv_ab
# 82976  2103-09-27 18:02:00           45.23  metavision    mv_ab
#
#       culture_starttime_delta   first_sterile_date
# 82975        41 days 07:55:00  2103-11-02 14:30:00
# 82976        42 days 07:55:00  2103-11-02 14:30:00
#
# [2 rows x 29 columns]

# %% [markdown]
# not great agreement between rx and prescription. again this is for the same hadm_id. lots of difference between the items prescribed and the times they were prescribed : /.
#
# now i should do same analysis but between the prescription table and the associated sterile culture.

# %%
ABrx_merged_16sterile_ntnul.head()
# Out:
#     row_id  subject_id  hadm_id  icustay_id   startdate     enddate drug_type  \
# 0  2366833       24915   194424    267059.0  2182-12-10  2182-12-10      MAIN
# 1  2366088       24915   194424    267059.0  2182-11-29  2182-12-24      MAIN
# 2  2366064       24915   194424    267059.0  2182-11-17  2182-11-20      MAIN
# 3  2366065       24915   194424    267059.0  2182-11-17  2182-11-29      MAIN
# 4  2367574       24915   194424    267059.0  2183-01-12  2183-01-15      MAIN
#
#                   drug drug_name_poe drug_name_generic         ...           \
# 0           Daptomycin           NaN               NaN         ...
# 1  Imipenem-Cilastatin           NaN               NaN         ...
# 2       Vancomycin HCl           NaN               NaN         ...
# 3  Imipenem-Cilastatin           NaN               NaN         ...
# 4         Levofloxacin           NaN               NaN         ...
#
#   route      rxcui  Antibiotics         dob gender      first_admittime  \
# 0    IV   404652.0         True  2129-04-20      F  2182-11-11 20:01:00
# 1    IV  1726216.0         True  2129-04-20      F  2182-11-11 20:01:00
# 2    IV   239209.0         True  2129-04-20      F  2182-11-11 20:01:00
# 3    IV  1726216.0         True  2129-04-20      F  2182-11-11 20:01:00
# 4    IV        NaN        False  2129-04-20      F  2182-11-11 20:01:00
#
#   first_admit_age dbsource pt_ab_db   first_sterile_date
# 0           53.56  carevue    cv_ab  2182-11-12 01:50:00
# 1           53.56  carevue    cv_ab  2182-11-12 01:50:00
# 2           53.56  carevue    cv_ab  2182-11-12 01:50:00
# 3           53.56  carevue    cv_ab  2182-11-12 01:50:00
# 4           53.56  carevue    cv_ab  2182-11-12 01:50:00
#
# [5 rows x 28 columns]

# %%
#task: find the row for each hadm_id that most closely matches the first sterile culture date in ABrx_merged_16sterile_ntnul. 
#rewrote this code in vectorized manner on 4/16/18. runs much faster,

#doing date delta between hadm_id associated sterile culture and 

def datetime_conversion_fxn(df,col_input):
    slice_obj= df[col_input]
    slice_obj= pd.to_datetime(slice_obj)
    slice_obj.dt.strftime('%Y-%m-%d %H:%M:%S')
    slice_obj= pd.to_datetime(slice_obj)

# ABrx_merged_16sterile_ntnul['startdate'] = pd.to_datetime(ABrx_merged_16sterile_ntnul_test['startdate'])
# ABrx_merged_16sterile_ntnul['startdate'] = ABrx_merged_16sterile_ntnul_test['startdate'].dt.strftime('%Y-%m-%d %H:%M:%S')
# ABrx_merged_16sterile_ntnul['startdate'] = pd.to_datetime(ABrx_merged_16sterile_ntnul_test['startdate'])


# ABrx_merged_16sterile_ntnul['first_sterile_date'] = pd.to_datetime(ABrx_merged_16sterile_ntnul_test['first_sterile_date'])
# ABrx_merged_16sterile_ntnul['first_sterile_date']= ABrx_merged_16sterile_ntnul_test['first_sterile_date'].dt.strftime('%Y-%m-%d %H:%M:%S')
# ABrx_merged_16sterile_ntnul['first_sterile_date'] = pd.to_datetime(ABrx_merged_16sterile_ntnul_test['first_sterile_date'])

#replaced above 6 lines of code with this
datetime_conversion_fxn(ABrx_merged_16sterile_ntnul,'startdate')
datetime_conversion_fxn(ABrx_merged_16sterile_ntnul,'first_sterile_date')

ABrx_merged_16sterile_ntnul['culture_starttime_delta'] =0 

#for element in range(len(ABrx_merged_16sterile_ntnul)):
#    ABrx_merged_16sterile_ntnul.iloc[element,28]= pd.Timedelta(ABrx_merged_16sterile_ntnul.iloc[element,4]-ABrx_merged_16sterile_ntnul.iloc[element,27], unit='d')


ABrx_merged_16sterile_ntnul['culture_starttime_delta']= ABrx_merged_16sterile_ntnul['startdate']-ABrx_merged_16sterile_ntnul['first_sterile_date']
# Out:
#     row_id  subject_id  hadm_id  icustay_id  startdate     enddate drug_type  \
# 0  2366833       24915   194424    267059.0 2182-12-10  2182-12-10      MAIN
# 1  2366088       24915   194424    267059.0 2182-11-29  2182-12-24      MAIN
# 2  2366064       24915   194424    267059.0 2182-11-17  2182-11-20      MAIN
# 3  2366065       24915   194424    267059.0 2182-11-17  2182-11-29      MAIN
# 4  2367574       24915   194424    267059.0 2183-01-12  2183-01-15      MAIN
#
#                   drug drug_name_poe drug_name_generic  \
# 0           Daptomycin           NaN               NaN
# 1  Imipenem-Cilastatin           NaN               NaN
# 2       Vancomycin HCl           NaN               NaN
# 3  Imipenem-Cilastatin           NaN               NaN
# 4         Levofloxacin           NaN               NaN
#
#             ...                 rxcui  Antibiotics         dob gender  \
# 0           ...              404652.0         True  2129-04-20      F
# 1           ...             1726216.0         True  2129-04-20      F
# 2           ...              239209.0         True  2129-04-20      F
# 3           ...             1726216.0         True  2129-04-20      F
# 4           ...                   NaN        False  2129-04-20      F
#
#        first_admittime first_admit_age dbsource pt_ab_db  first_sterile_date  \
# 0  2182-11-11 20:01:00           53.56  carevue    cv_ab 2182-11-12 01:50:00
# 1  2182-11-11 20:01:00           53.56  carevue    cv_ab 2182-11-12 01:50:00
# 2  2182-11-11 20:01:00           53.56  carevue    cv_ab 2182-11-12 01:50:00
# 3  2182-11-11 20:01:00           53.56  carevue    cv_ab 2182-11-12 01:50:00
# 4  2182-11-11 20:01:00           53.56  carevue    cv_ab 2182-11-12 01:50:00
#
#    culture_starttime_delta
# 0         27 days 22:10:00
# 1         16 days 22:10:00
# 2          4 days 22:10:00
# 3          4 days 22:10:00
# 4         60 days 22:10:00
#
# [5 rows x 29 columns]

# %%
# Out:
# 0   27 days 22:10:00
# 1   16 days 22:10:00
# 2    4 days 22:10:00
# 3    4 days 22:10:00
# 4   60 days 22:10:00
# Name: date delta, dtype: timedelta64[ns]

# %%
#now to select the rows for each hadm id that are closest to the sterile culture date.

#remember the eqn is: antibiotic start date - culture date, so if antibiotic start before culture it should be negative. 

#first fileter on only those which are negative. 
from datetime import timedelta
d = timedelta(days=0)

ABrx_merged_16sterile_ntnul_AB_before_sterile=ABrx_merged_16sterile_ntnul.loc[ABrx_merged_16sterile_ntnul.loc[:,'culture_starttime_delta']<d,:]

len(ABrx_merged_16sterile_ntnul_AB_before_sterile['subject_id'].unique())
# Out:
# 7247

# %%
#ABrx_merged_16sterile_ntnul.iloc[1,29]= pd.Timedelta(ABrx_merged_16sterile_ntnul.iloc[1,4]-ABrx_merged_16sterile_ntnul.iloc[1,27], unit='d')

# %%
print(max(compare_table['date delta']),min(compare_table['date delta']))
# Out:
# 33 days 10:45:00 -82 days +18:30:00

# %%
time_delta = pd.to_datetime(compare_table['date delta'].str.strip(), 
                                format='%m/%d/%y %H:%M:%S')

eruption_deltas = eruption_times.diff()

# %% [markdown]
# todo 4/16/18
#
# redo sterile culture time algorithm.#done
#
# #check new prescription table compariosn of culture time and start-time.
#
#
# filter discrepency tables for >30 discrepency. look at a few examples. which table makes more sense?
#
# also test haadm id vs icustay id vs subject id.
#
# highlight points in my python notebook, and send to nelson and dr Luo.
#
#
# try merging the two tables and selecting the first antibiotic date prior to each sterile culture.
#
# focus on compiling current results onto the forum and email.
#
# take screenshots of the jupyter notebook.
#
#
# CLEANUP order of jupyter notebook. restructure so it can all be run.
#
#     make a new clean notebook
#     start to wrap things in functions

# %%
#making functions, maybe makes life easier?

def bool_fxn(df,bool_col, bool_value):

def slicing_fxn(df,bool_col, bool_value):

    slice_result=df.loc[df.loc[:,bool_col]==bool_value, :]
    return(slice_result)

# %%
ABrx_merged_16sterile_ntnul.loc[ABrx_merged_16sterile_ntnul.loc[:,'culture_starttime_delta']<d,:]

# %%
slicing_fxn(ABrx_merged_16sterile_ntnul,'culture_starttime_delta', d)
# Out:
#          row_id  subject_id  hadm_id  icustay_id  startdate     enddate  \
# 4735    2802579       26083   120427    237983.0 2200-08-28  2200-08-29
# 6257    3256178       26753   102793    244475.0 2186-07-05  2186-07-05
# 6258    3256177       26753   102793    244475.0 2186-07-05  2186-07-14
# 9697    3283459       27811   157821    205161.0 2147-10-12  2147-10-13
# 45047   3844614       61526   197570    290165.0 2129-12-29  2129-12-29
# 45048   3844615       61526   197570    290165.0 2129-12-29  2129-12-31
# 47574   4098703       65999   126011    262821.0 2179-04-08  2179-04-09
# 47575   4098704       65999   126011    262821.0 2179-04-08  2179-04-19
# 51647   3826969       69758   119269    206671.0 2179-02-13  2179-02-15
# 90780    301147        4793   130489    254615.0 2178-03-02  2178-03-04
# 90781    303697        4793   130489    254615.0 2178-03-02  2178-03-08
# 92350   1485844        5709   180293    264169.0 2111-07-16  2111-07-19
# 98300    395955        7614   146426    202141.0 2177-01-03  2177-01-09
# 98304    395956        7614   146426    202141.0 2177-01-03  2177-01-04
# 103897  1805493       10856   142530    210856.0 2154-07-07  2154-07-10
#
#        drug_type                         drug                drug_name_poe  \
# 4735        MAIN   Piperacillin-Tazobactam Na                          NaN
# 6257        MAIN    Sulfameth/Trimethoprim DS    Sulfameth/Trimethoprim DS
# 6258        MAIN                 Azithromycin                 Azithromycin
# 9697        MAIN                   Vancomycin                          NaN
# 45047       MAIN      Piperacillin-Tazobactam                          NaN
# 45048       MAIN      Piperacillin-Tazobactam                          NaN
# 47574       MAIN                  Amoxicillin                  Amoxicillin
# 47575       MAIN               Clarithromycin               Clarithromycin
# 51647       MAIN                   Vancomycin                          NaN
# 90780       MAIN               Vancomycin HCl                          NaN
# 90781       MAIN                 Azithromycin                 Azithromycin
# 92350       MAIN  Amoxicillin-Clavulanic Acid  Amoxicillin-Clavulanic Acid
# 98300       MAIN                 Levofloxacin                          NaN
# 98304       MAIN               Vancomycin HCl                          NaN
# 103897      MAIN          Nystatin Oral Susp.          Nystatin Oral Susp.
#
#                   drug_name_generic     ...     Antibiotics         dob  \
# 4735                            NaN     ...            True  2116-05-27
# 6257      Sulfameth/Trimethoprim DS     ...            True  2142-11-12
# 6258                   Azithromycin     ...            True  2142-11-12
# 9697                            NaN     ...            True  2094-03-16
# 45047                           NaN     ...            True  2104-04-26
# 45048                           NaN     ...            True  2104-04-26
# 47574         AMOXicillin Oral Susp     ...            True  2136-07-18
# 47575   Clarithromycin (Suspension)     ...            True  2136-07-18
# 51647                           NaN     ...            True  2124-12-09
# 90780                           NaN     ...           False  2124-01-02
# 90781                  Azithromycin     ...            True  2124-01-02
# 92350   Amoxicillin-Clavulanic Acid     ...           False  2046-12-20
# 98300                           NaN     ...           False  2093-10-31
# 98304                           NaN     ...            True  2093-10-31
# 103897          Nystatin Oral Susp.     ...           False  2071-09-15
#
#         gender      first_admittime first_admit_age    dbsource pt_ab_db  \
# 4735         M  2200-08-18 22:44:00           84.23     carevue    cv_ab
# 6257         F  2186-06-30 01:56:00           43.63     carevue    cv_ab
# 6258         F  2186-06-30 01:56:00           43.63     carevue    cv_ab
# 9697         M  2147-10-06 17:04:00           53.56     carevue    cv_ab
# 45047        M  2129-12-24 04:21:00           25.66  metavision    mv_ab
# 45048        M  2129-12-24 04:21:00           25.66  metavision    mv_ab
# 47574        M  2179-04-03 00:32:00           42.71  metavision    mv_ab
# 47575        M  2179-04-03 00:32:00           42.71  metavision    mv_ab
# 51647        F  2179-02-08 01:47:00           54.17  metavision    mv_ab
# 90780        F  2178-02-25 01:22:00           54.15     carevue    cv_ab
# 90781        F  2178-02-25 01:22:00           54.15     carevue    cv_ab
# 92350        M  2110-03-10 07:15:00           63.22     carevue    cv_ab
# 98300        M  2174-10-15 19:54:00           80.95     carevue    cv_ab
# 98304        M  2174-10-15 19:54:00           80.95     carevue    cv_ab
# 103897       M  2154-07-02 21:40:00           82.79     carevue    cv_ab
#
#        culture_starttime_delta first_sterile_date  date delta
# 4735           5 days 00:00:00         2200-08-23      5 days
# 6257           5 days 00:00:00         2186-06-30      5 days
# 6258           5 days 00:00:00         2186-06-30      5 days
# 9697           5 days 00:00:00         2147-10-07      5 days
# 45047          5 days 00:00:00         2129-12-24      5 days
# 45048          5 days 00:00:00         2129-12-24      5 days
# 47574          5 days 00:00:00         2179-04-03      5 days
# 47575          5 days 00:00:00         2179-04-03      5 days
# 51647          5 days 00:00:00         2179-02-08      5 days
# 90780          5 days 00:00:00         2178-02-25      5 days
# 90781          5 days 00:00:00         2178-02-25      5 days
# 92350          5 days 00:00:00         2111-07-11      5 days
# 98300          5 days 00:00:00         2176-12-29      5 days
# 98304          5 days 00:00:00         2176-12-29      5 days
# 103897         5 days 00:00:00         2154-07-02      5 days
#
# [15 rows x 30 columns]

# %% [markdown]
# jupyter tips:
#
# Use joblib for caching output
# You thought your neural network for three days and now you are ready to build on top of it. But you forgot to plug your laptop to a power source and it runs out of batteries. So you scream: Why didn’t I pickle!? The answer is: because it is pain in the back. Managing file names, checking if the file exists, saving, loading… What to do instead? Use joblib.
#
# from sklearn.externals.joblib import Memory
# memory = Memory(cachedir='/tmp', verbose=0)
# @memory.cache
# def computation(p1, p2):
#     ...
# With three lines of code, you get caching of the output of any function. Joblib traces parameters passed to a function, and if the function has been called with the same parameters it returns the return value cached on a disk.
#
# 8. Make sections of the notebook self-contained
# Make sections of your notebook loosely bound. Use as little global variables as possible. If you wrap your cells in functions and you use joblib for caching, it is really inexpensive to call same code within each section. It’s better than making code reliable on the variables created several cells above.
#
# In general, try to limit the number of cells you have to re-run after the restart to continue on your work.
#
#
# When you create some utility function, create short tests using assert keyword. For example:
#
# def norm_scale(X, axis=0):
#     mx = np.max(X, axis=axis)
#     mi = np.min(X, axis=axis)
#     epsilon = 10**-32
#     return (X — mi) / (np.abs(mi) + mx + epsilon)
# norm = norm_scale(X)
# assert np.min(norm) >= 0
# assert np.max(norm) <= 1

# %%
from sklearn.externals.joblib import Memory
memory = Memory(cachedir='/tmp', verbose=0)

# %%
@memory.cache
def datetime_conversion_fxn(df,col_input):
    slice_obj= df[col_input]
    slice_obj= pd.to_datetime(slice_obj)
    slice_obj.dt.strftime('%Y-%m-%d %H:%M:%S')
    slice_obj= pd.to_datetime(slice_obj)

# ABrx_merged_16sterile_ntnul['startdate'] = pd.to_datetime(ABrx_merged_16sterile_ntnul_test['startdate'])
# ABrx_merged_16sterile_ntnul['startdate'] = ABrx_merged_16sterile_ntnul_test['startdate'].dt.strftime('%Y-%m-%d %H:%M:%S')
# ABrx_merged_16sterile_ntnul['startdate'] = pd.to_datetime(ABrx_merged_16sterile_ntnul_test['startdate'])


# ABrx_merged_16sterile_ntnul['first_sterile_date'] = pd.to_datetime(ABrx_merged_16sterile_ntnul_test['first_sterile_date'])
# ABrx_merged_16sterile_ntnul['first_sterile_date']= ABrx_merged_16sterile_ntnul_test['first_sterile_date'].dt.strftime('%Y-%m-%d %H:%M:%S')
# ABrx_merged_16sterile_ntnul['first_sterile_date'] = pd.to_datetime(ABrx_merged_16sterile_ntnul_test['first_sterile_date'])

#replaced above 6 lines of code with this
datetime_conversion_fxn(ABrx_merged_16sterile_ntnul,'startdate')
datetime_conversion_fxn(ABrx_merged_16sterile_ntnul,'first_sterile_date')
# Out:
# -----------------------------------------------------
# KeyboardInterrupt   Traceback (most recent call last)
# <ipython-input-139-1b29b056b0bd> in <module>()
#      17 #replaced above 6 lines of code with this
#      18 datetime_conversion_fxn(ABrx_merged_16sterile_ntnul,'startdate')
# ---> 19 datetime_conversion_fxn(ABrx_merged_16sterile_ntnul,'first_sterile_date')
#
# ~/anaconda/envs/rpy-env/lib/python3.6/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     560
#     561     def __call__(self, *args, **kwargs):
# --> 562         return self._cached_call(args, kwargs)[0]
#     563
#     564     def __reduce__(self):
#
# ~/anaconda/envs/rpy-env/lib/python3.6/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs)
#     497         # Compare the function code with the previous to see if the
#     498         # function code has changed
# --> 499         output_dir, argument_hash = self._get_output_dir(*args, **kwargs)
#     500         metadata = None
#     501         output_pickle_path = os.path.join(output_dir, 'output.pkl')
#
# ~/anaconda/envs/rpy-env/lib/python3.6/site-packages/sklearn/externals/joblib/memory.py in _get_output_dir(self, *args, **kwargs)
#     583             of the function called with the given arguments.
#     584         """
# --> 585         argument_hash = self._get_argument_hash(*args, **kwargs)
#     586         output_dir = os.path.join(self._get_func_dir(self.func),
#     587                                   argument_hash)
#
# ~/anaconda/envs/rpy-env/lib/python3.6/site-packages/sklearn/externals/joblib/memory.py in _get_argument_hash(self, *args, **kwargs)
#     577         return hashing.hash(filter_args(self.func, self.ignore,
#     578                                          args, kwargs),
# --> 579                              coerce_mmap=(self.mmap_mode is not None))
#     580
#     581     def _get_output_dir(self, *args, **kwargs):
#
# ~/anaconda/envs/rpy-env/lib/python3.6/site-packages/sklearn/externals/joblib/hashing.py in hash(obj, hash_name, coerce_mmap)
#     261     else:
#     262         hasher = Hasher(hash_name=hash_name)
# --> 263     return hasher.hash(obj)
#
# ~/anaconda/envs/rpy-env/lib/python3.6/site-packages/sklearn/externals/joblib/hashing.py in hash(self, obj, return_digest)
#      67     def hash(self, obj, return_digest=True):
#      68         try:
# ---> 69             self.dump(obj)
#      70         except pickle.PicklingError as e:
#      71             e.args += ('PicklingError while hashing %r: %r' % (obj, e),)
#
# ~/anaconda/envs/rpy-env/lib/python3.6/pickle.py in dump(self, obj)
#     407         if self.proto >= 4:
#     408             self.framer.start_framing()
# --> 409         self.save(obj)
#     410         self.write(STOP)
#     411         self.framer.end_framing()
#
# ~/anaconda/envs/rpy-env/lib/python3.6/site-packages/sklearn/externals/joblib/hashing.py in save(self, obj)
#     241             klass = obj.__class__
#     242             obj = (klass, ('HASHED', obj.descr))
# --> 243         Hasher.save(self, obj)
#     244
#     245
#
# ~/anaconda/envs/rpy-env/lib/python3.6/site-packages/sklearn/externals/joblib/hashing.py in save(self, obj)
#      93                 cls = obj.__self__.__class__
#      94                 obj = _MyHash(func_name, inst, cls)
# ---> 95         Pickler.save(self, obj)
#      96
#      97     def memoize(self, obj):
#
# ~/anaconda/envs/rpy-env/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# ~/anaconda/envs/rpy-env/lib/python3.6/pickle.py in save_dict(self, obj)
#     819
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#     823     dispatch[dict] = save_dict
#
# ~/anaconda/envs/rpy-env/lib/python3.6/site-packages/sklearn/externals/joblib/hashing.py in _batch_setitems(self, items)
#     145             # This fails on python 3 when keys are unorderable
#     146             # but we keep it in a try as it's faster.
# --> 147             Pickler._batch_setitems(self, iter(sorted(items)))
#     148         except TypeError:
#     149             # If keys are unorderable, sorting them using their hash. This is
#
# ~/anaconda/envs/rpy-env/lib/python3.6/pickle.py in _batch_setitems(self, items)
#     845                 for k, v in tmp:
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#     849             elif n:
#
# ~/anaconda/envs/rpy-env/lib/python3.6/site-packages/sklearn/externals/joblib/hashing.py in save(self, obj)
#     241             klass = obj.__class__
#     242             obj = (klass, ('HASHED', obj.descr))
# --> 243         Hasher.save(self, obj)
#     244
#     245
#
# ~/anaconda/envs/rpy-env/lib/python3.6/site-packages/sklearn/externals/joblib/hashing.py in save(self, obj)
#      93                 cls = obj.__self__.__class__
#      94                 obj = _MyHash(func_name, inst, cls)
# ---> 95         Pickler.save(self, obj)
#      96
#      97     def memoize(self, obj):
#
# ~/anaconda/envs/rpy-env/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     519
#     520         # Save the reduce() output and finally memoize the object
# --> 521         self.save_reduce(obj=obj, *rv)
#     522
#     523     def persistent_id(self, obj):
#
# ~/anaconda/envs/rpy-env/lib/python3.6/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     632
#     633         if state is not None:
# --> 634             save(state)
#     635             write(BUILD)
#     636
#
# ~/anaconda/envs/rpy-env/lib/python3.6/site-packages/sklearn/externals/joblib/hashing.py in save(self, obj)
#     241             klass = obj.__class__
#     242             obj = (klass, ('HASHED', obj.descr))
# --> 243         Hasher.save(self, obj)
#     244
#     245
#
# ~/anaconda/envs/rpy-env/lib/python3.6/site-packages/sklearn/externals/joblib/hashing.py in save(self, obj)
#      93                 cls = obj.__self__.__class__
#      94                 obj = _MyHash(func_name, inst, cls)
# ---> 95         Pickler.save(self, obj)
#      96
#      97     def memoize(self, obj):
#
# ~/anaconda/envs/rpy-env/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# ~/anaconda/envs/rpy-env/lib/python3.6/pickle.py in save_dict(self, obj)
#     819
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#     823     dispatch[dict] = save_dict
#
# ~/anaconda/envs/rpy-env/lib/python3.6/site-packages/sklearn/externals/joblib/hashing.py in _batch_setitems(self, items)
#     145             # This fails on python 3 when keys are unorderable
#     146             # but we keep it in a try as it's faster.
# --> 147             Pickler._batch_setitems(self, iter(sorted(items)))
#     148         except TypeError:
#     149             # If keys are unorderable, sorting them using their hash. This is
#
# ~/anaconda/envs/rpy-env/lib/python3.6/pickle.py in _batch_setitems(self, items)
#     845                 for k, v in tmp:
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#     849             elif n:
#
# ~/anaconda/envs/rpy-env/lib/python3.6/site-packages/sklearn/externals/joblib/hashing.py in save(self, obj)
#     241             klass = obj.__class__
#     242             obj = (klass, ('HASHED', obj.descr))
# --> 243         Hasher.save(self, obj)
#     244
#     245
#
# ~/anaconda/envs/rpy-env/lib/python3.6/site-packages/sklearn/externals/joblib/hashing.py in save(self, obj)
#      93                 cls = obj.__self__.__class__
#      94                 obj = _MyHash(func_name, inst, cls)
# ---> 95         Pickler.save(self, obj)
#      96
#      97     def memoize(self, obj):
#
# ~/anaconda/envs/rpy-env/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     519
#     520         # Save the reduce() output and finally memoize the object
# --> 521         self.save_reduce(obj=obj, *rv)
#     522
#     523     def persistent_id(self, obj):
#
# ~/anaconda/envs/rpy-env/lib/python3.6/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     632
#     633         if state is not None:
# --> 634             save(state)
#     635             write(BUILD)
#     636
#
# ~/anaconda/envs/rpy-env/lib/python3.6/site-packages/sklearn/externals/joblib/hashing.py in save(self, obj)
#     241             klass = obj.__class__
#     242             obj = (klass, ('HASHED', obj.descr))
# --> 243         Hasher.save(self, obj)
#     244
#     245
#
# ~/anaconda/envs/rpy-env/lib/python3.6/site-packages/sklearn/externals/joblib/hashing.py in save(self, obj)
#      93                 cls = obj.__self__.__class__
#      94                 obj = _MyHash(func_name, inst, cls)
# ---> 95         Pickler.save(self, obj)
#      96
#      97     def memoize(self, obj):
#
# ~/anaconda/envs/rpy-env/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# ~/anaconda/envs/rpy-env/lib/python3.6/pickle.py in save_tuple(self, obj)
#     749         write(MARK)
#     750         for element in obj:
# --> 751             save(element)
#     752
#     753         if id(obj) in memo:
#
# ~/anaconda/envs/rpy-env/lib/python3.6/site-packages/sklearn/externals/joblib/hashing.py in save(self, obj)
#     241             klass = obj.__class__
#     242             obj = (klass, ('HASHED', obj.descr))
# --> 243         Hasher.save(self, obj)
#     244
#     245
#
# ~/anaconda/envs/rpy-env/lib/python3.6/site-packages/sklearn/externals/joblib/hashing.py in save(self, obj)
#      93                 cls = obj.__self__.__class__
#      94                 obj = _MyHash(func_name, inst, cls)
# ---> 95         Pickler.save(self, obj)
#      96
#      97     def memoize(self, obj):
#
# ~/anaconda/envs/rpy-env/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# ~/anaconda/envs/rpy-env/lib/python3.6/pickle.py in save_list(self, obj)
#     779
#     780         self.memoize(obj)
# --> 781         self._batch_appends(obj)
#     782
#     783     dispatch[list] = save_list
#
# ~/anaconda/envs/rpy-env/lib/python3.6/pickle.py in _batch_appends(self, items)
#     803                 write(MARK)
#     804                 for x in tmp:
# --> 805                     save(x)
#     806                 write(APPENDS)
#     807             elif n:
#
# ~/anaconda/envs/rpy-env/lib/python3.6/site-packages/sklearn/externals/joblib/hashing.py in save(self, obj)
#     241             klass = obj.__class__
#     242             obj = (klass, ('HASHED', obj.descr))
# --> 243         Hasher.save(self, obj)
#     244
#     245
#
# ~/anaconda/envs/rpy-env/lib/python3.6/site-packages/sklearn/externals/joblib/hashing.py in save(self, obj)
#      93                 cls = obj.__self__.__class__
#      94                 obj = _MyHash(func_name, inst, cls)
# ---> 95         Pickler.save(self, obj)
#      96
#      97     def memoize(self, obj):
#
# ~/anaconda/envs/rpy-env/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     519
#     520         # Save the reduce() output and finally memoize the object
# --> 521         self.save_reduce(obj=obj, *rv)
#     522
#     523     def persistent_id(self, obj):
#
# ~/anaconda/envs/rpy-env/lib/python3.6/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     632
#     633         if state is not None:
# --> 634             save(state)
#     635             write(BUILD)
#     636
#
# ~/anaconda/envs/rpy-env/lib/python3.6/site-packages/sklearn/externals/joblib/hashing.py in save(self, obj)
#     241             klass = obj.__class__
#     242             obj = (klass, ('HASHED', obj.descr))
# --> 243         Hasher.save(self, obj)
#     244
#     245
#
# ~/anaconda/envs/rpy-env/lib/python3.6/site-packages/sklearn/externals/joblib/hashing.py in save(self, obj)
#      93                 cls = obj.__self__.__class__
#      94                 obj = _MyHash(func_name, inst, cls)
# ---> 95         Pickler.save(self, obj)
#      96
#      97     def memoize(self, obj):
#
# ~/anaconda/envs/rpy-env/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# ~/anaconda/envs/rpy-env/lib/python3.6/pickle.py in save_tuple(self, obj)
#     749         write(MARK)
#     750         for element in obj:
# --> 751             save(element)
#     752
#     753         if id(obj) in memo:
#
# ~/anaconda/envs/rpy-env/lib/python3.6/site-packages/sklearn/externals/joblib/hashing.py in save(self, obj)
#     241             klass = obj.__class__
#     242             obj = (klass, ('HASHED', obj.descr))
# --> 243         Hasher.save(self, obj)
#     244
#     245
#
# ~/anaconda/envs/rpy-env/lib/python3.6/site-packages/sklearn/externals/joblib/hashing.py in save(self, obj)
#      93                 cls = obj.__self__.__class__
#      94                 obj = _MyHash(func_name, inst, cls)
# ---> 95         Pickler.save(self, obj)
#      96
#      97     def memoize(self, obj):
#
# ~/anaconda/envs/rpy-env/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# ~/anaconda/envs/rpy-env/lib/python3.6/pickle.py in save_list(self, obj)
#     779
#     780         self.memoize(obj)
# --> 781         self._batch_appends(obj)
#     782
#     783     dispatch[list] = save_list
#
# ~/anaconda/envs/rpy-env/lib/python3.6/pickle.py in _batch_appends(self, items)
#     803                 write(MARK)
#     804                 for x in tmp:
# --> 805                     save(x)
#     806                 write(APPENDS)
#     807             elif n:
#
# ~/anaconda/envs/rpy-env/lib/python3.6/site-packages/sklearn/externals/joblib/hashing.py in save(self, obj)
#     241             klass = obj.__class__
#     242             obj = (klass, ('HASHED', obj.descr))
# --> 243         Hasher.save(self, obj)
#     244
#     245
#
# ~/anaconda/envs/rpy-env/lib/python3.6/site-packages/sklearn/externals/joblib/hashing.py in save(self, obj)
#      93                 cls = obj.__self__.__class__
#      94                 obj = _MyHash(func_name, inst, cls)
# ---> 95         Pickler.save(self, obj)
#      96
#      97     def memoize(self, obj):
#
# ~/anaconda/envs/rpy-env/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# ~/anaconda/envs/rpy-env/lib/python3.6/pickle.py in save_str(self, obj)
#     712                 self.write(BINUNICODE8 + pack("<Q", n) + encoded)
#     713             else:
# --> 714                 self.write(BINUNICODE + pack("<I", n) + encoded)
#     715         else:
#     716             obj = obj.replace("\\", "\\u005c")
#
# KeyboardInterrupt:
